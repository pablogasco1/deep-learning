# %%
import numpy as np
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from torchsummary import summary
from torchvision import datasets, transforms

# %% [markdown]
# # Example of CNN GAN, same as previous example but remove some CNN layers

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# create a guassian blur with different widths
n_images = 3000 # number of samples in total
img_size = 64


x = np.linspace(-4, 4, img_size)
X, Y = np.meshgrid(x, x)

images = torch.zeros((n_images, 1, img_size, img_size)) # create a tensor to hold the images

for i in range(n_images):
        # location and width of the gaussian blur
        center = 2*np.random.randn(2) # randomly shift the center of the gaussian blur
        width = np.random.rand() / 0.6  + 1.8 # randomly choose a width between 1.8 and 3.4
        
        gauss = np.exp(-((X - center[0])**2 + (Y - center[1])**2) / (2*width**2)) # create a gaussian blur with the given width and center
        gauss = gauss + np.random.randn(img_size, img_size) * 0.2 # add some noise to the image

        images[i] = torch.tensor(gauss).view(1, img_size, img_size) # store the image in the tensor

# normalize the images to be in the range [-1, 1]
images = (images - images.min()) / (images.max() - images.min()) # normalize to [0, 1]
images = images * 2 - 1 # scale to [-1, 1]

# create a dataloader for the images
dataset = TensorDataset(images)
data_loader = DataLoader(dataset, batch_size=128, shuffle=True)

# %%
images.min(), images.max()
# Out:
# (tensor(-1.), tensor(1.))

# %%
# visualize some samples
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i in range(5):
    axes[i].imshow(images[i, 0], cmap='jet', vmin=-0.5, vmax=0.5)

# %%
# create a linear discriminator and generator model
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        # input size is (1, 64, 64) and output is a single value representing the probability of being real
        # bias=False because we will use batch normalization, which has its own bias term
        self.conv1 = nn.Conv2d( 1,  64, kernel_size=4, stride=3, padding=0, bias=False) # size = (64, 21, 21)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=4, stride=3, padding=0, bias=False) # size = (128, 6, 6)
        self.conv3 = nn.Conv2d(128, 1, kernel_size=4, stride=3, padding=0, bias=False) # size = (1, 1, 1)
        
        # Apply batch normalization the the middle layers to stabilize training, but not to the first and last layers since 
        # they are directly connected to the input and output, respectively
        self.bn2 = nn.BatchNorm2d(128)

    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2) # use leaky relu to avoid dead neurons
        x = F.leaky_relu(self.bn2(self.conv2(x)), 0.2)
        x = torch.sigmoid(self.conv3(x)) 
        return x.view(-1, 1) # flatten the output to a single value per image
    
d_net = Discriminator().to(device)
print(summary(d_net, input_size=(1, 64, 64)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 21, 21]           1,024
#             Conv2d-2            [-1, 128, 6, 6]         131,072
#        BatchNorm2d-3            [-1, 128, 6, 6]             256
#             Conv2d-4              [-1, 1, 1, 1]           2,048
# ================================================================
# Total params: 134,400
# Trainable params: 134,400
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.29
# Params size (MB): 0.51
# Estimated Total Size (MB): 0.81
# ----------------------------------------------------------------
# None

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # input size is a noise vector of size 100 and output is an image of size (1, 64, 64)
        # bias=False because we will use batch normalization, which has its own bias term
        self.conv1 = nn.ConvTranspose2d(100, 512, kernel_size=4, stride=4, padding=0, bias=False) # size = (512, 4, 4)
        self.conv2 = nn.ConvTranspose2d(512, 256, kernel_size=4, stride=4, padding=0, bias=False) # size = (256, 16, 16)
        self.conv3 = nn.ConvTranspose2d(256, 1, kernel_size=4, stride=4, padding=0, bias=False) # size = (1, 64, 64)

        # here we apply bn to the first layer as well, since it is not directly connected to the input noise vector, but rather to the output of the first convolutional layer
        self.bn1 = nn.BatchNorm2d(512)
        self.bn2 = nn.BatchNorm2d(256)

    def forward(self, x):
        x = F.leaky_relu(self.bn1(self.conv1(x)), 0.2)
        x = F.leaky_relu(self.bn2(self.conv2(x)), 0.2)
        x = torch.tanh(self.conv3(x))
        x = x.view(-1, 1, 64, 64) # reshape the output to image format
        return x
    
g_net = Generator().to(device)
print(summary(g_net, input_size=(100, 1, 1)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 512, 4, 4]         819,200
#        BatchNorm2d-2            [-1, 512, 4, 4]           1,024
#    ConvTranspose2d-3          [-1, 256, 16, 16]       2,097,152
#        BatchNorm2d-4          [-1, 256, 16, 16]             512
#    ConvTranspose2d-5            [-1, 1, 64, 64]           4,096
# ================================================================
# Total params: 2,921,984
# Trainable params: 2,921,984
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.16
# Params size (MB): 11.15
# Estimated Total Size (MB): 12.30
# ----------------------------------------------------------------
# None

# %%
# simulate a forward pass through the generator and discriminator to check that the dimensions are correct
noise = torch.randn(1, 100, 1, 1).to(device)
fake_image = g_net(noise)
print(fake_image.shape) # should be (1, 1, 64, 64)
d_out = d_net(fake_image)
print(d_out.shape) # should be (1, 1)

# same for real images
X = next(iter(data_loader))[0].to(device) # get a batch of real images
real_image = X[0].unsqueeze(0) # get a single image and add a batch dimension
print(real_image.shape) # should be (1, 1, 64, 64)
d_out_real = d_net(real_image)
print(d_out_real.shape) # should be (1, 1)
# Out:
# torch.Size([1, 1, 64, 64])
# torch.Size([1, 1])
# torch.Size([1, 1, 64, 64])
# torch.Size([1, 1])

# %%
# create a function to train the GAN
def train_gan(d_net, d_optimizer, g_net, g_optimizer, train_loader, loss_fn, num_epochs=10):

    losses = np.zeros((num_epochs, 2)) # to store discriminator and generator losses
    discriminator_outputs = np.zeros((num_epochs, 2)) # to store discriminator outputs for real and fake images

    for epoch in range(num_epochs):
        loss_d_epoch = 0.0
        loss_g_epoch = 0.0
        d_out_real_epoch = 0.0
        d_out_fake_epoch = 0.0
        for (real_images,) in train_loader:
            batch_size = real_images.size(0) # get the actual batch size (last batch might be smaller)
            
            # A) Train Discriminator
            # 0) Create real and fake images and labels
            real_images = real_images.to(device)
            labels_real = torch.ones(batch_size, 1).to(device) # real labels

            noise = torch.randn(batch_size, 100, 1, 1).to(device)
            fake_images = g_net(noise)
            labels_fake = torch.zeros(batch_size, 1).to(device) # fake labels

            # 1) Train on real images
            output_real = d_net(real_images)
            d_loss_real = loss_fn(output_real, labels_real)

            # 2) Train on fake images
            output_fake = d_net(fake_images.detach()) # detach to avoid backprop through generator
            d_loss_fake = loss_fn(output_fake, labels_fake)

            # 3) Combine losses and update discriminator
            d_out_real_epoch += output_real.mean().item() # average output for real images
            d_out_fake_epoch += output_fake.mean().item() # average output for fake images
            loss_d_epoch += d_loss_real.item() + d_loss_fake.item()
            d_loss = d_loss_real + d_loss_fake

            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # B) Train Generator
            output_fake_for_g = d_net(fake_images) # don't detach here, we want gradients to flow to generator
            g_loss = loss_fn(output_fake_for_g, labels_real) # want generator to fool discriminator
            loss_g_epoch += g_loss.item()
            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

        discriminator_outputs[epoch, 0] = d_out_real_epoch / len(train_loader) # average discriminator output for real images
        discriminator_outputs[epoch, 1] = d_out_fake_epoch / len(train_loader) # average discriminator output for fake images   
        losses[epoch, 0] = loss_d_epoch / len(train_loader) # average discriminator loss for the epoch
        losses[epoch, 1] = loss_g_epoch / len(train_loader) # average generator loss for the epoch

        print(f"Epoch [{epoch+1}/{num_epochs}] - D Loss: {loss_d_epoch/len(train_loader):.4f}, G Loss: {loss_g_epoch/len(train_loader):.4f}")

    return losses, discriminator_outputs

# %%
# define loss function and optimizers for discriminator and generator
loss_fn = nn.BCELoss()

d_net = Discriminator().to(device)
g_net = Generator().to(device)

optimizer_D = torch.optim.Adam(d_net.parameters(), lr=0.0002, betas=(0.5, 0.999)) # GANS are very sensitive to learning rates
optimizer_G = torch.optim.Adam(g_net.parameters(), lr=0.0002, betas=(0.5, 0.999))

num_epochs = 200

losses, discriminator_outputs = train_gan(d_net, optimizer_D, g_net, optimizer_G, data_loader, loss_fn, num_epochs)
# Out:
# Epoch [1/200] - D Loss: 1.1132, G Loss: 1.7510
# Epoch [2/200] - D Loss: 0.3450, G Loss: 2.9376
# Epoch [3/200] - D Loss: 0.2407, G Loss: 3.1861
# Epoch [4/200] - D Loss: 0.3822, G Loss: 3.2449
# Epoch [5/200] - D Loss: 0.4681, G Loss: 2.9060
# Epoch [6/200] - D Loss: 0.4787, G Loss: 2.8325
# Epoch [7/200] - D Loss: 0.5281, G Loss: 2.5606
# Epoch [8/200] - D Loss: 0.6678, G Loss: 2.4194
# Epoch [9/200] - D Loss: 0.8990, G Loss: 2.0998
# Epoch [10/200] - D Loss: 0.8912, G Loss: 1.9215
# Epoch [11/200] - D Loss: 0.9413, G Loss: 1.7361
# Epoch [12/200] - D Loss: 1.1146, G Loss: 1.5527
# Epoch [13/200] - D Loss: 1.1518, G Loss: 1.4077
# Epoch [14/200] - D Loss: 1.2967, G Loss: 1.2846
# Epoch [15/200] - D Loss: 1.2883, G Loss: 1.1571
# Epoch [16/200] - D Loss: 1.3932, G Loss: 1.0143
# Epoch [17/200] - D Loss: 1.4189, G Loss: 0.9322
# Epoch [18/200] - D Loss: 1.3617, G Loss: 0.9317
# Epoch [19/200] - D Loss: 1.4019, G Loss: 0.8566
# Epoch [20/200] - D Loss: 1.3631, G Loss: 0.8657
# Epoch [21/200] - D Loss: 1.3991, G Loss: 0.7904
# Epoch [22/200] - D Loss: 1.3783, G Loss: 0.7814
# Epoch [23/200] - D Loss: 1.3727, G Loss: 0.7831
# Epoch [24/200] - D Loss: 1.3945, G Loss: 0.7563
# Epoch [25/200] - D Loss: 1.3828, G Loss: 0.7720
# Epoch [26/200] - D Loss: 1.3288, G Loss: 0.7958
# Epoch [27/200] - D Loss: 1.3725, G Loss: 0.7787
# Epoch [28/200] - D Loss: 1.3348, G Loss: 0.8015
# Epoch [29/200] - D Loss: 1.3130, G Loss: 0.8088
# Epoch [30/200] - D Loss: 1.3208, G Loss: 0.8200
# Epoch [31/200] - D Loss: 1.2721, G Loss: 0.8500
# Epoch [32/200] - D Loss: 1.3050, G Loss: 0.8325
# Epoch [33/200] - D Loss: 1.2414, G Loss: 0.8548
# Epoch [34/200] - D Loss: 1.2591, G Loss: 0.8476
# Epoch [35/200] - D Loss: 1.2575, G Loss: 0.8685
# Epoch [36/200] - D Loss: 1.2657, G Loss: 0.8552
# Epoch [37/200] - D Loss: 1.2410, G Loss: 0.8799
# Epoch [38/200] - D Loss: 1.2613, G Loss: 0.8808
# Epoch [39/200] - D Loss: 1.2664, G Loss: 0.8793
# Epoch [40/200] - D Loss: 1.2968, G Loss: 0.8882
# Epoch [41/200] - D Loss: 1.3198, G Loss: 0.9083
# Epoch [42/200] - D Loss: 1.3064, G Loss: 0.9016
# Epoch [43/200] - D Loss: 1.2899, G Loss: 0.9151
# Epoch [44/200] - D Loss: 1.2906, G Loss: 0.9136
# Epoch [45/200] - D Loss: 1.2974, G Loss: 0.9160
# Epoch [46/200] - D Loss: 1.3208, G Loss: 0.9141
# Epoch [47/200] - D Loss: 1.3214, G Loss: 0.8952
# Epoch [48/200] - D Loss: 1.3324, G Loss: 0.9201
# Epoch [49/200] - D Loss: 1.3572, G Loss: 0.8941
# Epoch [50/200] - D Loss: 1.3310, G Loss: 0.9054
# Epoch [51/200] - D Loss: 1.3369, G Loss: 0.9056
# Epoch [52/200] - D Loss: 1.3256, G Loss: 0.9477
# Epoch [53/200] - D Loss: 1.3676, G Loss: 0.8975
# Epoch [54/200] - D Loss: 1.3416, G Loss: 0.9213
# Epoch [55/200] - D Loss: 1.3951, G Loss: 0.8641
# Epoch [56/200] - D Loss: 1.3802, G Loss: 0.8831
# Epoch [57/200] - D Loss: 1.3673, G Loss: 0.8906
# Epoch [58/200] - D Loss: 1.3641, G Loss: 0.8790
# Epoch [59/200] - D Loss: 1.3907, G Loss: 0.8441
# Epoch [60/200] - D Loss: 1.3921, G Loss: 0.8321
# Epoch [61/200] - D Loss: 1.3932, G Loss: 0.8240
# Epoch [62/200] - D Loss: 1.3485, G Loss: 0.8582
# Epoch [63/200] - D Loss: 1.4048, G Loss: 0.8334
# Epoch [64/200] - D Loss: 1.3802, G Loss: 0.8279
# Epoch [65/200] - D Loss: 1.4742, G Loss: 0.7705
# Epoch [66/200] - D Loss: 1.4137, G Loss: 0.7954
# Epoch [67/200] - D Loss: 1.3831, G Loss: 0.7946
# Epoch [68/200] - D Loss: 1.3969, G Loss: 0.7963
# Epoch [69/200] - D Loss: 1.4078, G Loss: 0.7654
# Epoch [70/200] - D Loss: 1.4292, G Loss: 0.7598
# Epoch [71/200] - D Loss: 1.4134, G Loss: 0.7627
# Epoch [72/200] - D Loss: 1.4333, G Loss: 0.7392
# Epoch [73/200] - D Loss: 1.4085, G Loss: 0.7628
# Epoch [74/200] - D Loss: 1.4359, G Loss: 0.7212
# Epoch [75/200] - D Loss: 1.4468, G Loss: 0.7182
# Epoch [76/200] - D Loss: 1.4325, G Loss: 0.7413
# Epoch [77/200] - D Loss: 1.4453, G Loss: 0.7175
# Epoch [78/200] - D Loss: 1.4494, G Loss: 0.7071
# Epoch [79/200] - D Loss: 1.4262, G Loss: 0.7183
# Epoch [80/200] - D Loss: 1.4340, G Loss: 0.7176
# Epoch [81/200] - D Loss: 1.4317, G Loss: 0.7071
# Epoch [82/200] - D Loss: 1.4191, G Loss: 0.7042
# Epoch [83/200] - D Loss: 1.4281, G Loss: 0.7045
# Epoch [84/200] - D Loss: 1.4184, G Loss: 0.7143
# Epoch [85/200] - D Loss: 1.4081, G Loss: 0.7207
# Epoch [86/200] - D Loss: 1.4113, G Loss: 0.7084
# Epoch [87/200] - D Loss: 1.4267, G Loss: 0.7023
# Epoch [88/200] - D Loss: 1.4204, G Loss: 0.7051
# Epoch [89/200] - D Loss: 1.4053, G Loss: 0.7128
# Epoch [90/200] - D Loss: 1.4214, G Loss: 0.7077
# Epoch [91/200] - D Loss: 1.4281, G Loss: 0.6994
# Epoch [92/200] - D Loss: 1.4125, G Loss: 0.7100
# Epoch [93/200] - D Loss: 1.4205, G Loss: 0.7047
# Epoch [94/200] - D Loss: 1.4094, G Loss: 0.7030
# Epoch [95/200] - D Loss: 1.4094, G Loss: 0.7116
# Epoch [96/200] - D Loss: 1.4186, G Loss: 0.7063
# Epoch [97/200] - D Loss: 1.4187, G Loss: 0.7012
# Epoch [98/200] - D Loss: 1.4155, G Loss: 0.7050
# Epoch [99/200] - D Loss: 1.4061, G Loss: 0.7087
# Epoch [100/200] - D Loss: 1.4125, G Loss: 0.7054
# Epoch [101/200] - D Loss: 1.4183, G Loss: 0.7009
# Epoch [102/200] - D Loss: 1.4312, G Loss: 0.6999
# Epoch [103/200] - D Loss: 1.4170, G Loss: 0.7031
# Epoch [104/200] - D Loss: 1.4092, G Loss: 0.7023
# Epoch [105/200] - D Loss: 1.4112, G Loss: 0.7219
# Epoch [106/200] - D Loss: 1.4036, G Loss: 0.7095
# Epoch [107/200] - D Loss: 1.3891, G Loss: 0.7196
# Epoch [108/200] - D Loss: 1.4078, G Loss: 0.7184
# Epoch [109/200] - D Loss: 1.3950, G Loss: 0.7151
# Epoch [110/200] - D Loss: 1.4175, G Loss: 0.7249
# Epoch [111/200] - D Loss: 1.4062, G Loss: 0.7035
# Epoch [112/200] - D Loss: 1.4131, G Loss: 0.7200
# Epoch [113/200] - D Loss: 1.4043, G Loss: 0.7361
# Epoch [114/200] - D Loss: 1.4125, G Loss: 0.7135
# Epoch [115/200] - D Loss: 1.4026, G Loss: 0.7183
# Epoch [116/200] - D Loss: 1.4038, G Loss: 0.7059
# Epoch [117/200] - D Loss: 1.4019, G Loss: 0.7211
# Epoch [118/200] - D Loss: 1.4205, G Loss: 0.7202
# Epoch [119/200] - D Loss: 1.4009, G Loss: 0.7127
# Epoch [120/200] - D Loss: 1.3852, G Loss: 0.7312
# Epoch [121/200] - D Loss: 1.4149, G Loss: 0.7146
# Epoch [122/200] - D Loss: 1.4162, G Loss: 0.7148
# Epoch [123/200] - D Loss: 1.4025, G Loss: 0.7201
# Epoch [124/200] - D Loss: 1.4112, G Loss: 0.7143
# Epoch [125/200] - D Loss: 1.4030, G Loss: 0.7136
# Epoch [126/200] - D Loss: 1.3968, G Loss: 0.7254
# Epoch [127/200] - D Loss: 1.4070, G Loss: 0.7252
# Epoch [128/200] - D Loss: 1.4007, G Loss: 0.7154
# Epoch [129/200] - D Loss: 1.4224, G Loss: 0.7202
# Epoch [130/200] - D Loss: 1.3861, G Loss: 0.7150
# Epoch [131/200] - D Loss: 1.4235, G Loss: 0.7090
# Epoch [132/200] - D Loss: 1.3986, G Loss: 0.7295
# Epoch [133/200] - D Loss: 1.3990, G Loss: 0.7301
# Epoch [134/200] - D Loss: 1.4115, G Loss: 0.7159
# Epoch [135/200] - D Loss: 1.4168, G Loss: 0.7219
# Epoch [136/200] - D Loss: 1.3999, G Loss: 0.7240
# Epoch [137/200] - D Loss: 1.4098, G Loss: 0.7132
# Epoch [138/200] - D Loss: 1.4145, G Loss: 0.7228
# Epoch [139/200] - D Loss: 1.3973, G Loss: 0.7174
# Epoch [140/200] - D Loss: 1.3953, G Loss: 0.7234
# Epoch [141/200] - D Loss: 1.4109, G Loss: 0.7167
# Epoch [142/200] - D Loss: 1.3890, G Loss: 0.7229
# Epoch [143/200] - D Loss: 1.4072, G Loss: 0.7145
# Epoch [144/200] - D Loss: 1.4241, G Loss: 0.7202
# Epoch [145/200] - D Loss: 1.4165, G Loss: 0.7155
# Epoch [146/200] - D Loss: 1.3874, G Loss: 0.7234
# Epoch [147/200] - D Loss: 1.4095, G Loss: 0.7264
# Epoch [148/200] - D Loss: 1.4210, G Loss: 0.7145
# Epoch [149/200] - D Loss: 1.4165, G Loss: 0.7130
# Epoch [150/200] - D Loss: 1.4077, G Loss: 0.7091
# Epoch [151/200] - D Loss: 1.4031, G Loss: 0.7386
# Epoch [152/200] - D Loss: 1.4196, G Loss: 0.7239
# Epoch [153/200] - D Loss: 1.4088, G Loss: 0.7411
# Epoch [154/200] - D Loss: 1.4076, G Loss: 0.7332
# Epoch [155/200] - D Loss: 1.4004, G Loss: 0.7093
# Epoch [156/200] - D Loss: 1.3915, G Loss: 0.7429
# Epoch [157/200] - D Loss: 1.4103, G Loss: 0.7136
# Epoch [158/200] - D Loss: 1.4021, G Loss: 0.7287
# Epoch [159/200] - D Loss: 1.4049, G Loss: 0.7294
# Epoch [160/200] - D Loss: 1.3850, G Loss: 0.7426
# Epoch [161/200] - D Loss: 1.4154, G Loss: 0.7322
# Epoch [162/200] - D Loss: 1.3806, G Loss: 0.7258
# Epoch [163/200] - D Loss: 1.4057, G Loss: 0.7156
# Epoch [164/200] - D Loss: 1.3867, G Loss: 0.7341
# Epoch [165/200] - D Loss: 1.4094, G Loss: 0.7259
# Epoch [166/200] - D Loss: 1.3983, G Loss: 0.7398
# Epoch [167/200] - D Loss: 1.4080, G Loss: 0.7370
# Epoch [168/200] - D Loss: 1.4116, G Loss: 0.7287
# Epoch [169/200] - D Loss: 1.3918, G Loss: 0.7177
# Epoch [170/200] - D Loss: 1.3992, G Loss: 0.7310
# Epoch [171/200] - D Loss: 1.3905, G Loss: 0.7366
# Epoch [172/200] - D Loss: 1.4077, G Loss: 0.7058
# Epoch [173/200] - D Loss: 1.4003, G Loss: 0.7273
# Epoch [174/200] - D Loss: 1.3892, G Loss: 0.7265
# Epoch [175/200] - D Loss: 1.4067, G Loss: 0.7293
# Epoch [176/200] - D Loss: 1.3974, G Loss: 0.7360
# Epoch [177/200] - D Loss: 1.3976, G Loss: 0.7332
# Epoch [178/200] - D Loss: 1.3874, G Loss: 0.7334
# Epoch [179/200] - D Loss: 1.4047, G Loss: 0.7184
# Epoch [180/200] - D Loss: 1.3832, G Loss: 0.7397
# Epoch [181/200] - D Loss: 1.4020, G Loss: 0.7194
# Epoch [182/200] - D Loss: 1.3874, G Loss: 0.7399
# Epoch [183/200] - D Loss: 1.4061, G Loss: 0.7297
# Epoch [184/200] - D Loss: 1.3956, G Loss: 0.7244
# Epoch [185/200] - D Loss: 1.4047, G Loss: 0.7122
# Epoch [186/200] - D Loss: 1.4117, G Loss: 0.7139
# Epoch [187/200] - D Loss: 1.3858, G Loss: 0.7268
# Epoch [188/200] - D Loss: 1.3884, G Loss: 0.7194
# Epoch [189/200] - D Loss: 1.4175, G Loss: 0.7110
# Epoch [190/200] - D Loss: 1.3939, G Loss: 0.7219
# Epoch [191/200] - D Loss: 1.3939, G Loss: 0.7214
# Epoch [192/200] - D Loss: 1.3946, G Loss: 0.7239
# Epoch [193/200] - D Loss: 1.4091, G Loss: 0.7233
# Epoch [194/200] - D Loss: 1.3933, G Loss: 0.7360
# Epoch [195/200] - D Loss: 1.3996, G Loss: 0.7172
# Epoch [196/200] - D Loss: 1.4039, G Loss: 0.7285
# Epoch [197/200] - D Loss: 1.4027, G Loss: 0.7170
# Epoch [198/200] - D Loss: 1.3881, G Loss: 0.7211
# Epoch [199/200] - D Loss: 1.3928, G Loss: 0.7218
# Epoch [200/200] - D Loss: 1.3997, G Loss: 0.7347

# %%
# plot the losses and discriminator outputs
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(losses[:, 0], label='Discriminator Loss')
plt.plot(losses[:, 1], label='Generator Loss')
plt.title('Losses')
plt.xlabel('Epoch')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(discriminator_outputs[:, 0], label='Discriminator Output (Real)')
plt.plot(discriminator_outputs[:, 1], label='Discriminator Output (Fake)')
plt.title('Discriminator Outputs')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# if observed more in detail, the discriminator and generator loss iterate, this means
# that when the discriminator goes up and it starts to discriminate very well, the generator
# realizes and starts to generate better images, but then the discriminator has more issues to distinguis
# so it is a bucle, where the losses go up and down.

# %%
# visualize some samples
g_net.eval() # set generator to evaluation mode
with torch.no_grad():
    noise = torch.randn(16, 100, 1, 1).to(device) # generate 16 random noise vectors
    fake_images = g_net(noise).cpu() # generate fake images and move to CPU
    fake_images = fake_images.view(-1, 1, img_size, img_size) # reshape to image format
    fig, axes = plt.subplots(4, 4, figsize=(8, 8))
    for i in range(16):
        ax = axes[i//4, i%4]
        ax.imshow(fake_images[i].squeeze(), cmap='jet', vmin=-0.5, vmax=0.5)
        ax.axis('off')
    plt.show()
    
# by removing some conv2d layers we have remove complexity to the GAN, and it is not able
# to capture the patterns
