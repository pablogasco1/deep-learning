# %%
import numpy as np
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from torchsummary import summary
from torchvision import datasets, transforms

# %% [markdown]
# # Example of CNN GAN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# create a guassian blur with different widths
n_images = 3000 # number of samples in total
img_size = 64


x = np.linspace(-4, 4, img_size)
X, Y = np.meshgrid(x, x)

images = torch.zeros((n_images, 1, img_size, img_size)) # create a tensor to hold the images

for i in range(n_images):
        # location and width of the gaussian blur
        center = 2*np.random.randn(2) # randomly shift the center of the gaussian blur
        width = np.random.rand() / 0.6  + 1.8 # randomly choose a width between 1.8 and 3.4
        
        gauss = np.exp(-((X - center[0])**2 + (Y - center[1])**2) / (2*width**2)) # create a gaussian blur with the given width and center
        gauss = gauss + np.random.randn(img_size, img_size) * 0.2 # add some noise to the image

        images[i] = torch.tensor(gauss).view(1, img_size, img_size) # store the image in the tensor

# normalize the images to be in the range [-1, 1]
images = (images - images.min()) / (images.max() - images.min()) # normalize to [0, 1]
images = images * 2 - 1 # scale to [-1, 1]

# create a dataloader for the images
dataset = TensorDataset(images)
data_loader = DataLoader(dataset, batch_size=128, shuffle=True)

# %%
images.min(), images.max()
# Out:
# (tensor(-1.), tensor(1.))

# %%
# visualize some samples
fig, axes = plt.subplots(1, 5, figsize=(15, 3))
for i in range(5):
    axes[i].imshow(images[i, 0], cmap='jet', vmin=-0.5, vmax=0.5)

# %%
# create a linear discriminator and generator model
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        # input size is (1, 64, 64) and output is a single value representing the probability of being real
        # bias=False because we will use batch normalization, which has its own bias term
        self.conv1 = nn.Conv2d( 1,  64, kernel_size=4, stride=2, padding=1, bias=False) # size = (64, 32, 32)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False) # size = (128, 16, 16)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False) # size = (256, 8, 8)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False) # size = (512, 4, 4)
        self.conv5 = nn.Conv2d(512,   1, kernel_size=4, stride=1, padding=0, bias=False) # size = (1, 1, 1)
        
        # Apply batch normalization the the middle layers to stabilize training, but not to the first and last layers since 
        # they are directly connected to the input and output, respectively
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(256)
        self.bn4 = nn.BatchNorm2d(512)

    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2) # use leaky relu to avoid dead neurons
        x = F.leaky_relu(self.bn2(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.bn3(self.conv3(x)), 0.2)
        x = F.leaky_relu(self.bn4(self.conv4(x)), 0.2)
        x = torch.sigmoid(self.conv5(x)) # output is in range [0, 1] to represent the probability of being real
        return x.view(-1, 1) # flatten the output to a single value per image
    
d_net = Discriminator().to(device)
print(summary(d_net, input_size=(1, 64, 64)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,024
#             Conv2d-2          [-1, 128, 16, 16]         131,072
#        BatchNorm2d-3          [-1, 128, 16, 16]             256
#             Conv2d-4            [-1, 256, 8, 8]         524,288
#        BatchNorm2d-5            [-1, 256, 8, 8]             512
#             Conv2d-6            [-1, 512, 4, 4]       2,097,152
#        BatchNorm2d-7            [-1, 512, 4, 4]           1,024
#             Conv2d-8              [-1, 1, 1, 1]           8,192
# ================================================================
# Total params: 2,763,520
# Trainable params: 2,763,520
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 1.38
# Params size (MB): 10.54
# Estimated Total Size (MB): 11.93
# ----------------------------------------------------------------
# None

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        # input size is a noise vector of size 100 and output is an image of size (1, 64, 64)
        # bias=False because we will use batch normalization, which has its own bias term
        self.conv1 = nn.ConvTranspose2d(100, 512, kernel_size=4, stride=1, padding=0, bias=False) # size = (512, 4, 4)
        self.conv2 = nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False) # size = (256, 8, 8)
        self.conv3 = nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False) # size = (128, 16, 16)
        self.conv4 = nn.ConvTranspose2d(128,  64, kernel_size=4, stride=2, padding=1, bias=False) # size = (64, 32, 32)
        self.conv5 = nn.ConvTranspose2d( 64,   1, kernel_size=4, stride=2, padding=1, bias=False) # size = (1, 64, 64)

        # here we apply bn to the first layer as well, since it is not directly connected to the input noise vector, but rather to the output of the first convolutional layer
        self.bn1 = nn.BatchNorm2d(512)
        self.bn2 = nn.BatchNorm2d(256)
        self.bn3 = nn.BatchNorm2d(128)
        self.bn4 = nn.BatchNorm2d(64)

    def forward(self, x):
        x = F.leaky_relu(self.bn1(self.conv1(x)), 0.2)
        x = F.leaky_relu(self.bn2(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.bn3(self.conv3(x)), 0.2)
        x = F.leaky_relu(self.bn4(self.conv4(x)), 0.2)
        x = torch.tanh(self.conv5(x)) # output is in range [-1, 1] to match the normalized input images
        x = x.view(-1, 1, 64, 64) # reshape the output to image format
        return x
    
g_net = Generator().to(device)
print(summary(g_net, input_size=(100, 1, 1)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1            [-1, 512, 4, 4]         819,200
#        BatchNorm2d-2            [-1, 512, 4, 4]           1,024
#    ConvTranspose2d-3            [-1, 256, 8, 8]       2,097,152
#        BatchNorm2d-4            [-1, 256, 8, 8]             512
#    ConvTranspose2d-5          [-1, 128, 16, 16]         524,288
#        BatchNorm2d-6          [-1, 128, 16, 16]             256
#    ConvTranspose2d-7           [-1, 64, 32, 32]         131,072
#        BatchNorm2d-8           [-1, 64, 32, 32]             128
#    ConvTranspose2d-9            [-1, 1, 64, 64]           1,024
# ================================================================
# Total params: 3,574,656
# Trainable params: 3,574,656
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.91
# Params size (MB): 13.64
# Estimated Total Size (MB): 15.54
# ----------------------------------------------------------------
# None

# %%
# simulate a forward pass through the generator and discriminator to check that the dimensions are correct
noise = torch.randn(1, 100, 1, 1).to(device)
fake_image = g_net(noise)
print(fake_image.shape) # should be (1, 1, 64, 64)
d_out = d_net(fake_image)
print(d_out.shape) # should be (1, 1)

# same for real images
X = next(iter(data_loader))[0].to(device) # get a batch of real images
real_image = X[0].unsqueeze(0) # get a single image and add a batch dimension
print(real_image.shape) # should be (1, 1, 64, 64)
d_out_real = d_net(real_image)
print(d_out_real.shape) # should be (1, 1)
# Out:
# torch.Size([1, 1, 64, 64])
# torch.Size([1, 1])
# torch.Size([1, 1, 64, 64])
# torch.Size([1, 1])

# %%
# create a function to train the GAN
def train_gan(d_net, d_optimizer, g_net, g_optimizer, train_loader, loss_fn, num_epochs=10):

    losses = np.zeros((num_epochs, 2)) # to store discriminator and generator losses
    discriminator_outputs = np.zeros((num_epochs, 2)) # to store discriminator outputs for real and fake images

    for epoch in range(num_epochs):
        loss_d_epoch = 0.0
        loss_g_epoch = 0.0
        d_out_real_epoch = 0.0
        d_out_fake_epoch = 0.0
        for (real_images,) in train_loader:
            batch_size = real_images.size(0) # get the actual batch size (last batch might be smaller)
            
            # A) Train Discriminator
            # 0) Create real and fake images and labels
            real_images = real_images.to(device)
            labels_real = torch.ones(batch_size, 1).to(device) # real labels

            noise = torch.randn(batch_size, 100, 1, 1).to(device)
            fake_images = g_net(noise)
            labels_fake = torch.zeros(batch_size, 1).to(device) # fake labels

            # 1) Train on real images
            output_real = d_net(real_images)
            d_loss_real = loss_fn(output_real, labels_real)

            # 2) Train on fake images
            output_fake = d_net(fake_images.detach()) # detach to avoid backprop through generator
            d_loss_fake = loss_fn(output_fake, labels_fake)

            # 3) Combine losses and update discriminator
            d_out_real_epoch += output_real.mean().item() # average output for real images
            d_out_fake_epoch += output_fake.mean().item() # average output for fake images
            loss_d_epoch += d_loss_real.item() + d_loss_fake.item()
            d_loss = d_loss_real + d_loss_fake

            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # B) Train Generator
            output_fake_for_g = d_net(fake_images) # don't detach here, we want gradients to flow to generator
            g_loss = loss_fn(output_fake_for_g, labels_real) # want generator to fool discriminator
            loss_g_epoch += g_loss.item()
            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

        discriminator_outputs[epoch, 0] = d_out_real_epoch / len(train_loader) # average discriminator output for real images
        discriminator_outputs[epoch, 1] = d_out_fake_epoch / len(train_loader) # average discriminator output for fake images   
        losses[epoch, 0] = loss_d_epoch / len(train_loader) # average discriminator loss for the epoch
        losses[epoch, 1] = loss_g_epoch / len(train_loader) # average generator loss for the epoch

        print(f"Epoch [{epoch+1}/{num_epochs}] - D Loss: {loss_d_epoch/len(train_loader):.4f}, G Loss: {loss_g_epoch/len(train_loader):.4f}")

    return losses, discriminator_outputs

# %%
# define loss function and optimizers for discriminator and generator
loss_fn = nn.BCELoss()

d_net = Discriminator().to(device)
g_net = Generator().to(device)

optimizer_D = torch.optim.Adam(d_net.parameters(), lr=0.0002, betas=(0.5, 0.999)) # GANS are very sensitive to learning rates
optimizer_G = torch.optim.Adam(g_net.parameters(), lr=0.0002, betas=(0.5, 0.999))

num_epochs = 200

losses, discriminator_outputs = train_gan(d_net, optimizer_D, g_net, optimizer_G, data_loader, loss_fn, num_epochs)
# Out:
# Epoch [1/200] - D Loss: 0.6583, G Loss: 6.4057
# Epoch [2/200] - D Loss: 0.9932, G Loss: 3.8173
# Epoch [3/200] - D Loss: 0.5783, G Loss: 3.0279
# Epoch [4/200] - D Loss: 0.2588, G Loss: 4.5511
# Epoch [5/200] - D Loss: 0.2610, G Loss: 5.4500
# Epoch [6/200] - D Loss: 0.4676, G Loss: 4.9926
# Epoch [7/200] - D Loss: 0.8830, G Loss: 4.0885
# Epoch [8/200] - D Loss: 0.9870, G Loss: 2.2742
# Epoch [9/200] - D Loss: 1.0070, G Loss: 2.2506
# Epoch [10/200] - D Loss: 0.9574, G Loss: 2.0230
# Epoch [11/200] - D Loss: 0.9186, G Loss: 1.9862
# Epoch [12/200] - D Loss: 0.8914, G Loss: 2.2274
# Epoch [13/200] - D Loss: 0.9509, G Loss: 2.1155
# Epoch [14/200] - D Loss: 1.0046, G Loss: 2.1655
# Epoch [15/200] - D Loss: 0.9837, G Loss: 1.9618
# Epoch [16/200] - D Loss: 1.0514, G Loss: 2.3661
# Epoch [17/200] - D Loss: 1.0677, G Loss: 2.2576
# Epoch [18/200] - D Loss: 1.0624, G Loss: 1.9786
# Epoch [19/200] - D Loss: 1.0414, G Loss: 2.2803
# Epoch [20/200] - D Loss: 1.0844, G Loss: 2.3157
# Epoch [21/200] - D Loss: 1.2054, G Loss: 2.0226
# Epoch [22/200] - D Loss: 1.0805, G Loss: 2.3683
# Epoch [23/200] - D Loss: 1.1468, G Loss: 1.8631
# Epoch [24/200] - D Loss: 1.0117, G Loss: 2.5974
# Epoch [25/200] - D Loss: 1.0872, G Loss: 2.5562
# Epoch [26/200] - D Loss: 1.1512, G Loss: 2.6781
# Epoch [27/200] - D Loss: 1.0154, G Loss: 2.5280
# Epoch [28/200] - D Loss: 1.1514, G Loss: 2.9092
# Epoch [29/200] - D Loss: 1.0183, G Loss: 2.5770
# Epoch [30/200] - D Loss: 0.9653, G Loss: 3.1087
# Epoch [31/200] - D Loss: 1.0565, G Loss: 2.7955
# Epoch [32/200] - D Loss: 0.9325, G Loss: 2.8176
# Epoch [33/200] - D Loss: 0.9819, G Loss: 3.3729
# Epoch [34/200] - D Loss: 0.9506, G Loss: 3.5033
# Epoch [35/200] - D Loss: 0.9568, G Loss: 3.2092
# Epoch [36/200] - D Loss: 1.0027, G Loss: 3.4120
# Epoch [37/200] - D Loss: 0.8831, G Loss: 3.2988
# Epoch [38/200] - D Loss: 0.8195, G Loss: 3.6503
# Epoch [39/200] - D Loss: 0.8986, G Loss: 3.3654
# Epoch [40/200] - D Loss: 0.8417, G Loss: 3.5848
# Epoch [41/200] - D Loss: 0.7962, G Loss: 3.8621
# Epoch [42/200] - D Loss: 0.8656, G Loss: 3.7945
# Epoch [43/200] - D Loss: 0.6076, G Loss: 4.0973
# Epoch [44/200] - D Loss: 0.8014, G Loss: 3.6882
# Epoch [45/200] - D Loss: 0.6770, G Loss: 3.8699
# Epoch [46/200] - D Loss: 0.8276, G Loss: 4.0226
# Epoch [47/200] - D Loss: 0.7654, G Loss: 3.6521
# Epoch [48/200] - D Loss: 0.6439, G Loss: 4.3734
# Epoch [49/200] - D Loss: 0.6764, G Loss: 4.6240
# Epoch [50/200] - D Loss: 0.5714, G Loss: 4.7233
# Epoch [51/200] - D Loss: 0.6607, G Loss: 4.1764
# Epoch [52/200] - D Loss: 0.7573, G Loss: 4.7309
# Epoch [53/200] - D Loss: 0.6519, G Loss: 4.6423
# Epoch [54/200] - D Loss: 0.5348, G Loss: 4.7080
# Epoch [55/200] - D Loss: 0.7945, G Loss: 4.8332
# Epoch [56/200] - D Loss: 0.5863, G Loss: 4.3543
# Epoch [57/200] - D Loss: 0.4904, G Loss: 5.1060
# Epoch [58/200] - D Loss: 0.5878, G Loss: 5.1258
# Epoch [59/200] - D Loss: 0.5032, G Loss: 5.3028
# Epoch [60/200] - D Loss: 0.5671, G Loss: 5.1920
# Epoch [61/200] - D Loss: 0.4581, G Loss: 4.8534
# Epoch [62/200] - D Loss: 0.4730, G Loss: 5.4011
# Epoch [63/200] - D Loss: 0.5145, G Loss: 5.6436
# Epoch [64/200] - D Loss: 0.5195, G Loss: 5.2931
# Epoch [65/200] - D Loss: 0.3590, G Loss: 5.2912
# Epoch [66/200] - D Loss: 0.5937, G Loss: 5.8381
# Epoch [67/200] - D Loss: 0.4488, G Loss: 5.2422
# Epoch [68/200] - D Loss: 0.4919, G Loss: 5.6133
# Epoch [69/200] - D Loss: 0.4375, G Loss: 5.3324
# Epoch [70/200] - D Loss: 0.3961, G Loss: 5.7269
# Epoch [71/200] - D Loss: 0.4399, G Loss: 6.4105
# Epoch [72/200] - D Loss: 0.3595, G Loss: 5.9902
# Epoch [73/200] - D Loss: 0.5075, G Loss: 6.3493
# Epoch [74/200] - D Loss: 0.3993, G Loss: 5.9216
# Epoch [75/200] - D Loss: 0.3179, G Loss: 5.8999
# Epoch [76/200] - D Loss: 0.5728, G Loss: 6.3462
# Epoch [77/200] - D Loss: 0.4057, G Loss: 5.4684
# Epoch [78/200] - D Loss: 0.3557, G Loss: 5.9077
# Epoch [79/200] - D Loss: 0.3771, G Loss: 6.2409
# Epoch [80/200] - D Loss: 0.4694, G Loss: 6.4062
# Epoch [81/200] - D Loss: 0.3624, G Loss: 6.0868
# Epoch [82/200] - D Loss: 0.4147, G Loss: 6.1108
# Epoch [83/200] - D Loss: 0.3731, G Loss: 6.4949
# Epoch [84/200] - D Loss: 0.4008, G Loss: 6.1494
# Epoch [85/200] - D Loss: 0.4662, G Loss: 6.6374
# Epoch [86/200] - D Loss: 0.4320, G Loss: 6.3757
# Epoch [87/200] - D Loss: 0.4354, G Loss: 6.3030
# Epoch [88/200] - D Loss: 0.3938, G Loss: 5.6693
# Epoch [89/200] - D Loss: 0.3728, G Loss: 6.0574
# Epoch [90/200] - D Loss: 0.3330, G Loss: 5.5669
# Epoch [91/200] - D Loss: 0.4151, G Loss: 6.1639
# Epoch [92/200] - D Loss: 0.3680, G Loss: 5.8768
# Epoch [93/200] - D Loss: 0.3455, G Loss: 6.1606
# Epoch [94/200] - D Loss: 0.3569, G Loss: 6.3285
# Epoch [95/200] - D Loss: 0.3293, G Loss: 6.1867
# Epoch [96/200] - D Loss: 0.3327, G Loss: 6.4133
# Epoch [97/200] - D Loss: 0.4125, G Loss: 6.8178
# Epoch [98/200] - D Loss: 0.3181, G Loss: 5.5350
# Epoch [99/200] - D Loss: 0.3679, G Loss: 6.1320
# Epoch [100/200] - D Loss: 0.3711, G Loss: 6.0195
# Epoch [101/200] - D Loss: 0.3342, G Loss: 5.7389
# Epoch [102/200] - D Loss: 0.3950, G Loss: 6.3570
# Epoch [103/200] - D Loss: 0.3267, G Loss: 5.9419
# Epoch [104/200] - D Loss: 0.3711, G Loss: 5.9829
# Epoch [105/200] - D Loss: 0.3184, G Loss: 5.5406
# Epoch [106/200] - D Loss: 0.3146, G Loss: 5.7938
# Epoch [107/200] - D Loss: 0.3130, G Loss: 5.6887
# Epoch [108/200] - D Loss: 0.3095, G Loss: 5.7012
# Epoch [109/200] - D Loss: 0.5185, G Loss: 7.1255
# Epoch [110/200] - D Loss: 0.3765, G Loss: 6.3611
# Epoch [111/200] - D Loss: 0.4050, G Loss: 6.1276
# Epoch [112/200] - D Loss: 0.3847, G Loss: 6.1749
# Epoch [113/200] - D Loss: 0.3435, G Loss: 5.9249
# Epoch [114/200] - D Loss: 0.3213, G Loss: 5.9766
# Epoch [115/200] - D Loss: 0.3139, G Loss: 5.7037
# Epoch [116/200] - D Loss: 0.3286, G Loss: 5.9023
# Epoch [117/200] - D Loss: 0.2876, G Loss: 5.6571
# Epoch [118/200] - D Loss: 0.4075, G Loss: 6.3583
# Epoch [119/200] - D Loss: 0.3182, G Loss: 5.7960
# Epoch [120/200] - D Loss: 0.3243, G Loss: 5.6599
# Epoch [121/200] - D Loss: 0.3693, G Loss: 5.8971
# Epoch [122/200] - D Loss: 0.3331, G Loss: 5.8905
# Epoch [123/200] - D Loss: 0.3560, G Loss: 5.7284
# Epoch [124/200] - D Loss: 0.3179, G Loss: 5.8094
# Epoch [125/200] - D Loss: 0.3206, G Loss: 5.4732
# Epoch [126/200] - D Loss: 0.3275, G Loss: 5.7252
# Epoch [127/200] - D Loss: 0.4155, G Loss: 6.4524
# Epoch [128/200] - D Loss: 0.3019, G Loss: 5.3216
# Epoch [129/200] - D Loss: 0.3438, G Loss: 5.5798
# Epoch [130/200] - D Loss: 0.3460, G Loss: 5.6534
# Epoch [131/200] - D Loss: 0.3773, G Loss: 5.9251
# Epoch [132/200] - D Loss: 0.3834, G Loss: 5.9635
# Epoch [133/200] - D Loss: 0.4164, G Loss: 7.0292
# Epoch [134/200] - D Loss: 0.3274, G Loss: 5.5413
# Epoch [135/200] - D Loss: 0.3513, G Loss: 5.7941
# Epoch [136/200] - D Loss: 0.3251, G Loss: 5.6041
# Epoch [137/200] - D Loss: 0.3899, G Loss: 6.5017
# Epoch [138/200] - D Loss: 0.3654, G Loss: 5.9592
# Epoch [139/200] - D Loss: 0.3816, G Loss: 6.0107
# Epoch [140/200] - D Loss: 0.3497, G Loss: 5.6782
# Epoch [141/200] - D Loss: 0.3655, G Loss: 5.9764
# Epoch [142/200] - D Loss: 0.5942, G Loss: 6.5409
# Epoch [143/200] - D Loss: 0.3646, G Loss: 5.7398
# Epoch [144/200] - D Loss: 0.3922, G Loss: 6.0478
# Epoch [145/200] - D Loss: 0.3330, G Loss: 5.3306
# Epoch [146/200] - D Loss: 0.3411, G Loss: 5.4963
# Epoch [147/200] - D Loss: 0.3695, G Loss: 5.9078
# Epoch [148/200] - D Loss: 0.3702, G Loss: 5.6552
# Epoch [149/200] - D Loss: 0.3145, G Loss: 5.2590
# Epoch [150/200] - D Loss: 0.5045, G Loss: 6.4506
# Epoch [151/200] - D Loss: 0.3820, G Loss: 5.6915
# Epoch [152/200] - D Loss: 0.3303, G Loss: 5.0575
# Epoch [153/200] - D Loss: 0.3733, G Loss: 5.3798
# Epoch [154/200] - D Loss: 0.3664, G Loss: 5.6254
# Epoch [155/200] - D Loss: 0.3258, G Loss: 5.3121
# Epoch [156/200] - D Loss: 0.5157, G Loss: 6.3787
# Epoch [157/200] - D Loss: 0.3671, G Loss: 5.7238
# Epoch [158/200] - D Loss: 0.3553, G Loss: 5.2139
# Epoch [159/200] - D Loss: 0.3540, G Loss: 5.4173
# Epoch [160/200] - D Loss: 0.3848, G Loss: 5.4074
# Epoch [161/200] - D Loss: 0.3868, G Loss: 5.7199
# Epoch [162/200] - D Loss: 0.3564, G Loss: 5.3437
# Epoch [163/200] - D Loss: 0.3390, G Loss: 5.0401
# Epoch [164/200] - D Loss: 0.3787, G Loss: 5.0580
# Epoch [165/200] - D Loss: 0.5909, G Loss: 6.2768
# Epoch [166/200] - D Loss: 0.3501, G Loss: 5.0263
# Epoch [167/200] - D Loss: 0.3606, G Loss: 4.9418
# Epoch [168/200] - D Loss: 0.3691, G Loss: 5.2890
# Epoch [169/200] - D Loss: 0.3219, G Loss: 5.1944
# Epoch [170/200] - D Loss: 0.4279, G Loss: 5.8211
# Epoch [171/200] - D Loss: 0.3898, G Loss: 5.6428
# Epoch [172/200] - D Loss: 0.3895, G Loss: 5.3571
# Epoch [173/200] - D Loss: 0.4034, G Loss: 5.5879
# Epoch [174/200] - D Loss: 0.4486, G Loss: 5.7664
# Epoch [175/200] - D Loss: 0.3782, G Loss: 5.6358
# Epoch [176/200] - D Loss: 0.3860, G Loss: 5.3464
# Epoch [177/200] - D Loss: 0.3769, G Loss: 5.3693
# Epoch [178/200] - D Loss: 0.3683, G Loss: 5.3141
# Epoch [179/200] - D Loss: 0.3523, G Loss: 5.1454
# Epoch [180/200] - D Loss: 0.3472, G Loss: 5.1806
# Epoch [181/200] - D Loss: 0.4120, G Loss: 5.6560
# Epoch [182/200] - D Loss: 0.4412, G Loss: 5.8745
# Epoch [183/200] - D Loss: 0.4087, G Loss: 5.3324
# Epoch [184/200] - D Loss: 0.3689, G Loss: 4.9874
# Epoch [185/200] - D Loss: 0.5818, G Loss: 6.1249
# Epoch [186/200] - D Loss: 0.4303, G Loss: 5.3089
# Epoch [187/200] - D Loss: 0.3803, G Loss: 5.0972
# Epoch [188/200] - D Loss: 0.3660, G Loss: 5.0830
# Epoch [189/200] - D Loss: 0.3924, G Loss: 5.2170
# Epoch [190/200] - D Loss: 0.3976, G Loss: 5.1409
# Epoch [191/200] - D Loss: 0.3912, G Loss: 5.0661
# Epoch [192/200] - D Loss: 0.5363, G Loss: 5.7466
# Epoch [193/200] - D Loss: 0.4071, G Loss: 5.2359
# Epoch [194/200] - D Loss: 0.3804, G Loss: 4.9150
# Epoch [195/200] - D Loss: 0.3748, G Loss: 4.9335
# Epoch [196/200] - D Loss: 0.4226, G Loss: 5.4224
# Epoch [197/200] - D Loss: 0.5879, G Loss: 5.8143
# Epoch [198/200] - D Loss: 0.4211, G Loss: 4.8156
# Epoch [199/200] - D Loss: 0.4369, G Loss: 5.0992
# Epoch [200/200] - D Loss: 0.3869, G Loss: 5.0537

# %%
# plot the losses and discriminator outputs
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(losses[:, 0], label='Discriminator Loss')
plt.plot(losses[:, 1], label='Generator Loss')
plt.title('Losses')
plt.xlabel('Epoch')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(discriminator_outputs[:, 0], label='Discriminator Output (Real)')
plt.plot(discriminator_outputs[:, 1], label='Discriminator Output (Fake)')
plt.title('Discriminator Outputs')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# if observed more in detail, the discriminator and generator loss iterate, this means
# that when the discriminator goes up and it starts to discriminate very well, the generator
# realizes and starts to generate better images, but then the discriminator has more issues to distinguis
# so it is a bucle, where the losses go up and down.

# %%
# visualize some samples
g_net.eval() # set generator to evaluation mode
with torch.no_grad():
    noise = torch.randn(16, 100, 1, 1).to(device) # generate 16 random noise vectors
    fake_images = g_net(noise).cpu() # generate fake images and move to CPU
    fake_images = fake_images.view(-1, 1, img_size, img_size) # reshape to image format
    fig, axes = plt.subplots(4, 4, figsize=(8, 8))
    for i in range(16):
        ax = axes[i//4, i%4]
        ax.imshow(fake_images[i].squeeze(), cmap='jet', vmin=-0.5, vmax=0.5)
        ax.axis('off')
    plt.show()
