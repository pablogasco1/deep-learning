# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import torchvision.datasets as datasets
import sklearn.metrics as metrics

# %% [markdown]
# # Check how the models behave when we train an all the categories except 7

# %%
mnist_train = datasets.MNIST(root="./data", train=True, download=True)
mnist_test = datasets.MNIST(root="./data", train=False, download=True)

X_train = mnist_train.data.float() / 255.0 # normalize between 0 and 1
y_train = mnist_train.targets.long()
X_test = mnist_test.data.float() / 255.0
y_test = mnist_test.targets.long()

# drop the cases of 7s but just on the train set
X_train = X_train[y_train!=7]
y_train = y_train[y_train!=7]

# and test just on 7s
X_test = X_test[y_test==7]
y_test = y_test[y_test==7]

# %%
# Convert into pytorch tensors
train_ds = TensorDataset(X_train, y_train)
test_ds = TensorDataset(X_test, y_test)

batch_size = 32
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, drop_last=True)
test_dl = DataLoader(test_ds, batch_size=test_ds.tensors[0].shape[0], shuffle=False)

# %%
class MNIST_FNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28, 64) 
        self.fc2 = nn.Linear(64, 32) 
        #self.fc3 = nn.Linear(32, 32)  
        self.fc4 = nn.Linear(32, 10)    

    def forward(self, x):
        x = torch.flatten(x, start_dim=1) # flatten the image, keep the batch dimension
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        #x = F.relu(self.fc3(x))
        x = self.fc4(x) 
        return x

def train_one_epoch(model, train_dl, optimizer, loss_fn):
    model.train()
    batch_acc = []
    batch_loss = []
    for X_batch, y_batch in train_dl:
        output = model(X_batch)
        loss = loss_fn(output, y_batch)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        batch_acc_item = (output.argmax(dim=1) == y_batch).float().mean().item()
        batch_acc.append(batch_acc_item)
        batch_loss.append(loss.item())
        
    return np.mean(batch_acc), np.mean(batch_loss)

def train_model(model, train_dl, test_dl, optimizer, loss_fn, epochs):
    
    train_acc = np.zeros(epochs)
    test_acc = np.zeros(epochs)
    losses = np.zeros(epochs)
    
    for epoch in range(epochs):
        train_acc[epoch], losses[epoch] = train_one_epoch(model, train_dl, optimizer, loss_fn)
        
        model.eval()
        with torch.no_grad():
            for X_batch, y_batch in test_dl:
                output = model(X_batch)
                test_acc[epoch] = (output.argmax(dim=1) == y_batch).float().mean().item()
                
    return train_acc, test_acc, losses

# %%
# Experiment
learning_rate = 0.01
epochs = 50

# IMPORTANT: the loss fun can be reused for multiple models, it doesnt store any state,
# but the optimizer needs to be redefined for each model since it stores the state of the parameters
loss_fn = nn.CrossEntropyLoss() # CrossEntropyLoss combines nn.LogSoftmax() and nn.NLLLoss()

model = MNIST_FNN()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
train_acc, test_acc, losses = train_model(model, train_dl, test_dl, optimizer, loss_fn, epochs)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].plot(train_acc, label="Train Accuracy")
ax[0].plot(test_acc, label="Test Accuracy")
ax[0].set_title(f"Final Test Accuracy: {test_acc[-1]:.2f}")
ax[0].set_xlabel("Epoch")
ax[0].set_ylabel("Accuracy")
ax[0].legend()

ax[1].plot(losses, label="Train Loss")
ax[1].set_title("Loss over epochs")
ax[1].set_xlabel("Epoch")
ax[1].set_ylabel("Loss")
ax[1].legend()
plt.show()

# %%
# plot the images and the labels predicted by the model
fig, ax = plt.subplots(1, 5, figsize=(15, 3))
for i in range(5):
    img = X_test[i].reshape(28, 28)
    true_label = y_test[i].item()
    with torch.no_grad():
        pred_label = model(X_test[i].unsqueeze(0)).argmax(dim=1).item()
    
    ax[i].imshow(img, cmap="gray")
    ax[i].set_title(f"True: {true_label}, Pred: {pred_label}")
    ax[i].axis("off")

# more or less the model will try to approximate the 7s to the most similar number

# %%
# show the frequency of the predicted labels
pred_labels = model(X_test).argmax(dim=1)
plt.hist(pred_labels.cpu().numpy(), bins=np.arange(11)-0.5, rwidth=0.8)

# 7 is most similar to 9, 2 or 3 following the model logics
# Out:
# (array([  2.,  12., 104., 245.,  18.,   2.,   3.,   0.,  13., 228.]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Check how the models behave when we reduce the numbers of 7 in the training

# %%
mnist_train = datasets.MNIST(root="./data", train=True, download=True)
mnist_test = datasets.MNIST(root="./data", train=False, download=True)

X_train = mnist_train.data.float() / 255.0 # normalize between 0 and 1
y_train = mnist_train.targets.long()
X_test = mnist_test.data.float() / 255.0
y_test = mnist_test.targets.long()

# leave just 500 examples of 7s in the train set
X_train_7 = X_train[y_train==7][:500]
y_train_7 = y_train[y_train==7][:500]
X_train_no7 = X_train[y_train!=7]
y_train_no7 = y_train[y_train!=7]
X_train = torch.cat([X_train_no7, X_train_7], dim=0)
y_train = torch.cat([y_train_no7, y_train_7], dim=0)

train_ds = TensorDataset(X_train, y_train)
test_ds = TensorDataset(X_test, y_test)

batch_size = 32
train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True, drop_last=True)
test_dl = DataLoader(test_ds, batch_size=test_ds.tensors[0].shape[0], shuffle=False)

# %%
# check now the distribution of each label in the train set
plt.hist(y_train.cpu().numpy(), bins=np.arange(11)-0.5, rwidth=0.8)
# Out:
# (array([5923., 6742., 5958., 6131., 5842., 5421., 5918.,  500., 5851.,
#         5949.]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5]),
#  <BarContainer object of 10 artists>)

# %%
learning_rate = 0.01
epochs = 50

loss_fn = nn.CrossEntropyLoss() 
model = MNIST_FNN()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

train_acc, test_acc, losses = train_model(model, train_dl, test_dl, optimizer, loss_fn, epochs)

# %%
y_pred_test = model(X_test).argmax(dim=1)
y_pred_train = model(X_train).argmax(dim=1)

train_metrics = [0, 0, 0, 0]
test_metrics = [0, 0, 0, 0]

# accuracy is already a global measure, is not computed by category like the others
train_metrics[0] = metrics.accuracy_score(y_train, y_pred_train) 
train_metrics[1] = metrics.precision_score(y_train, y_pred_train, average="weighted")
train_metrics[2] = metrics.recall_score(y_train, y_pred_train, average="weighted")
train_metrics[3] = metrics.f1_score(y_train, y_pred_train, average="weighted")

test_metrics[0] = metrics.accuracy_score(y_test, y_pred_test)
test_metrics[1] = metrics.precision_score(y_test, y_pred_test, average="weighted")
test_metrics[2] = metrics.recall_score(y_test, y_pred_test, average="weighted")
test_metrics[3] = metrics.f1_score(y_test, y_pred_test, average="weighted")

plt.bar(np.arange(4)-0.2, train_metrics, width=0.4, label="Train")
plt.bar(np.arange(4)+0.2, test_metrics, width=0.4, label="Test")
plt.xticks(np.arange(4), ["Accuracy", "Precision", "Recall", "F1-score"])
plt.ylim(0.9, 1.01)
plt.legend()
plt.show()

# we can see that removing the 7s didnt hurt a lot the overall performance

# %%
# plot the results by category
fig = plt.figure(figsize=(10, 3))
plt.bar(np.arange(10)-0.2, metrics.precision_score(y_test, y_pred_test, average=None), width=0.4, label="Precision")
plt.bar(np.arange(10)+0.2, metrics.recall_score(y_test, y_pred_test, average=None), width=0.4, label="Recall")
plt.xticks(np.arange(10), [str(i) for i in range(10)])
plt.ylim(0.8, 1)
plt.legend()
plt.show()

# we can see that the recall has increase for 7 in the test set, this means the model is ignoring a lot of 7s,
# it has a bias to say no for this category which is expected since we have very few 7s in the train set, but 
# the precision remains high, which means that when the model predicts a 7, it is usually correct.

# %%
# plot the confusion matrix for train and test
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
cm_train = metrics.confusion_matrix(y_train, y_pred_train, normalize="true")
cm_test = metrics.confusion_matrix(y_test, y_pred_test, normalize="true")
im_train = ax[0].imshow(cm_train, cmap="Blues", vmin=0, vmax=0.05)
im_test = ax[1].imshow(cm_test, cmap="Blues", vmin=0, vmax=0.05)
ax[0].set_title("Train Confusion Matrix")
ax[0].set_xlabel("Predicted")
ax[0].set_ylabel("True")
ax[0].set_xticks(np.arange(10))
ax[0].set_yticks(np.arange(10))
ax[1].set_title("Test Confusion Matrix")
ax[1].set_xlabel("Predicted")
ax[1].set_ylabel("True")
ax[1].set_xticks(np.arange(10))
ax[1].set_yticks(np.arange(10))
fig.colorbar(im_train, ax=ax[0])
fig.colorbar(im_test, ax=ax[1])
plt.show()

# we see than when the True label is a 7 the model is predicting mostly 9s, but also some 2s and 3s, 
# which is consistent with the previous results.
