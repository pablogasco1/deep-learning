# %%
import numpy as np
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from torchsummary import summary
from torchvision import datasets, transforms

# %% [markdown]
# # Example of LINEAR GAN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# import mnist dataset

transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.5,), (0.5,))
])

small_dataset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# select just 3 images (trouser, sneaker, pullover) using small_dataset.class_to_idx
class_to_idx = small_dataset.class_to_idx
print(class_to_idx)

selected_classes = ['Trouser', 'Sneaker', 'Pullover']
selected_indices = [class_to_idx[cls] for cls in selected_classes]
print(selected_indices)

small_dataset.targets = torch.tensor(small_dataset.targets)
mask = torch.isin(small_dataset.targets, torch.tensor(selected_indices))
small_dataset.data = small_dataset.data[mask]
small_dataset.targets = small_dataset.targets[mask]

data_loader = DataLoader(small_dataset, batch_size=128, shuffle=True)
# Out:
# {'T-shirt/top': 0, 'Trouser': 1, 'Pullover': 2, 'Dress': 3, 'Coat': 4, 'Sandal': 5, 'Shirt': 6, 'Sneaker': 7, 'Bag': 8, 'Ankle boot': 9}
# [1, 7, 2]
# /tmp/ipykernel_1371012/3511629871.py:18: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   small_dataset.targets = torch.tensor(small_dataset.targets)

# %%
# create a linear discriminator and generator model
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.fc1 = nn.Linear(28*28, 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, 1)

    def forward(self, x):
        x = x.view(-1, 28*28) # flatten the input image, equivalent to nn.Flatten()
        x = F.leaky_relu(self.fc1(x))
        x = F.leaky_relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x
    
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.fc1 = nn.Linear(64, 256) # input is a 64-dim noise vector
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, 28*28)

    def forward(self, x):
        x = F.leaky_relu(self.fc1(x))
        x = F.leaky_relu(self.fc2(x))
        x = torch.tanh(self.fc3(x)) # output is in range [-1, 1] to match the normalized input images
        x = x.view(-1, 1, 28, 28) # reshape the output to image format
        return x
    
d_net = Discriminator().to(device)
g_net = Generator().to(device)
print(summary(d_net, input_size=(1, 28, 28)))
print(summary(g_net, input_size=(64,)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 256]         200,960
#             Linear-2                  [-1, 256]          65,792
#             Linear-3                    [-1, 1]             257
# ================================================================
# Total params: 267,009
# Trainable params: 267,009
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 1.02
# Estimated Total Size (MB): 1.03
# ----------------------------------------------------------------
# None
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 256]          16,640
#             Linear-2                  [-1, 256]          65,792
#             Linear-3                  [-1, 784]         201,488
# ================================================================
# Total params: 283,920
# Trainable params: 283,920
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 1.08
# Estimated Total Size (MB): 1.09
# ----------------------------------------------------------------
# None

# %%
# test the generator and discriminator with random noise and real images
noise = torch.randn(1, 64).to(device)
fake_image = g_net(noise)[0] # generate a fake image from random noise, take the first image in the batch
real_images, _ = next(iter(data_loader))
real_image = real_images[0].to(device)

output_real = d_net(real_image)
output_fake = d_net(fake_image)


print("Fake image shape:", fake_image.shape) # should be (1, 1, 28, 28)
print("Real image shape:", real_image.shape) # should be (1, 1, 28, 28)

print(f"Discriminator output value (real): {output_real.item():.2f} shape: {output_real.shape}") # should be (1, 1) since batch size is 1
print(f"Discriminator output value (fake): {output_fake.item():.2f} shape: {output_fake.shape}") # should be (1, 1) since batch size is 1

# visualize the fake image generated by the generator
fake_image = fake_image.cpu().detach().numpy().squeeze() # convert to numpy array and remove batch and channel dimensions
plt.imshow(fake_image, cmap='gray')
plt.show()
# Out:
# Fake image shape: torch.Size([1, 28, 28])
# Real image shape: torch.Size([1, 28, 28])
# Discriminator output value (real): 0.45 shape: torch.Size([1, 1])
# Discriminator output value (fake): 0.48 shape: torch.Size([1, 1])

# %%
# create a function to train the GAN
def train_gan(d_net, d_optimizer, g_net, g_optimizer, train_loader, loss_fn, num_epochs=10):

    losses = np.zeros((num_epochs, 2)) # to store discriminator and generator losses
    discriminator_outputs = np.zeros((num_epochs, 2)) # to store discriminator outputs for real and fake images

    for epoch in range(num_epochs):
        loss_d_epoch = 0.0
        loss_g_epoch = 0.0
        d_out_real_epoch = 0.0
        d_out_fake_epoch = 0.0
        for real_images, _ in train_loader:
            batch_size = real_images.size(0) # get the actual batch size (last batch might be smaller)
            
            # A) Train Discriminator
            # 0) Create real and fake images and labels
            real_images = real_images.to(device)
            labels_real = torch.ones(batch_size, 1).to(device) # real labels

            noise = torch.randn(batch_size, 64).to(device)
            fake_images = g_net(noise)
            labels_fake = torch.zeros(batch_size, 1).to(device) # fake labels

            # 1) Train on real images
            output_real = d_net(real_images)
            d_loss_real = loss_fn(output_real, labels_real)

            # 2) Train on fake images
            output_fake = d_net(fake_images.detach()) # detach to avoid backprop through generator
            d_loss_fake = loss_fn(output_fake, labels_fake)

            # 3) Combine losses and update discriminator
            d_out_real_epoch += output_real.mean().item() # average output for real images
            d_out_fake_epoch += output_fake.mean().item() # average output for fake images
            loss_d_epoch += d_loss_real.item() + d_loss_fake.item()
            d_loss = d_loss_real + d_loss_fake

            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # B) Train Generator
            output_fake_for_g = d_net(fake_images) # don't detach here, we want gradients to flow to generator
            g_loss = loss_fn(output_fake_for_g, labels_real) # want generator to fool discriminator
            loss_g_epoch += g_loss.item()
            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

        discriminator_outputs[epoch, 0] = d_out_real_epoch / len(train_loader) # average discriminator output for real images
        discriminator_outputs[epoch, 1] = d_out_fake_epoch / len(train_loader) # average discriminator output for fake images   
        losses[epoch, 0] = loss_d_epoch / len(train_loader) # average discriminator loss for the epoch
        losses[epoch, 1] = loss_g_epoch / len(train_loader) # average generator loss for the epoch

        print(f"Epoch [{epoch+1}/{num_epochs}] - D Loss: {loss_d_epoch/len(train_loader):.4f}, G Loss: {loss_g_epoch/len(train_loader):.4f}")

    return losses, discriminator_outputs

# %%
# define loss function and optimizers for discriminator and generator
loss_fn = nn.BCELoss()

d_net = Discriminator().to(device)
g_net = Generator().to(device)

optimizer_D = torch.optim.Adam(d_net.parameters(), lr=0.0003) # GANS are very sensitive to learning rates
optimizer_G = torch.optim.Adam(g_net.parameters(), lr=0.0003)

num_epochs = 500

losses, discriminator_outputs = train_gan(d_net, optimizer_D, g_net, optimizer_G, data_loader, loss_fn, num_epochs)
# Out:
# Epoch [1/500] - D Loss: 0.9604, G Loss: 0.6606
# Epoch [2/500] - D Loss: 0.9781, G Loss: 0.9083
# Epoch [3/500] - D Loss: 0.3173, G Loss: 2.2323
# Epoch [4/500] - D Loss: 0.1597, G Loss: 2.8042
# Epoch [5/500] - D Loss: 0.4162, G Loss: 1.7314
# Epoch [6/500] - D Loss: 0.1361, G Loss: 2.8950
# Epoch [7/500] - D Loss: 0.2402, G Loss: 2.1762
# Epoch [8/500] - D Loss: 0.2870, G Loss: 2.0064
# Epoch [9/500] - D Loss: 0.1284, G Loss: 2.6763
# Epoch [10/500] - D Loss: 0.0659, G Loss: 3.4917
# Epoch [11/500] - D Loss: 0.0562, G Loss: 4.6256
# Epoch [12/500] - D Loss: 0.0745, G Loss: 4.3892
# Epoch [13/500] - D Loss: 0.0685, G Loss: 4.6888
# Epoch [14/500] - D Loss: 0.0457, G Loss: 5.4228
# Epoch [15/500] - D Loss: 0.0247, G Loss: 6.2941
# Epoch [16/500] - D Loss: 0.0136, G Loss: 5.9284
# Epoch [17/500] - D Loss: 0.0388, G Loss: 5.2150
# Epoch [18/500] - D Loss: 0.0238, G Loss: 4.9992
# Epoch [19/500] - D Loss: 0.1040, G Loss: 3.9273
# Epoch [20/500] - D Loss: 0.0322, G Loss: 5.0583
# Epoch [21/500] - D Loss: 0.0475, G Loss: 4.5515
# Epoch [22/500] - D Loss: 0.0373, G Loss: 4.7844
# Epoch [23/500] - D Loss: 0.0253, G Loss: 5.0859
# Epoch [24/500] - D Loss: 0.0453, G Loss: 4.9103
# Epoch [25/500] - D Loss: 0.0660, G Loss: 4.9082
# Epoch [26/500] - D Loss: 0.0892, G Loss: 4.4486
# Epoch [27/500] - D Loss: 0.0551, G Loss: 5.2736
# Epoch [28/500] - D Loss: 0.0440, G Loss: 5.8208
# Epoch [29/500] - D Loss: 0.0296, G Loss: 6.3791
# Epoch [30/500] - D Loss: 0.0354, G Loss: 6.0915
# Epoch [31/500] - D Loss: 0.0652, G Loss: 5.2545
# Epoch [32/500] - D Loss: 0.0233, G Loss: 6.0536
# Epoch [33/500] - D Loss: 0.0396, G Loss: 5.6053
# Epoch [34/500] - D Loss: 0.0455, G Loss: 6.0065
# Epoch [35/500] - D Loss: 0.0261, G Loss: 6.1353
# Epoch [36/500] - D Loss: 0.0340, G Loss: 6.3362
# Epoch [37/500] - D Loss: 0.0340, G Loss: 5.9839
# Epoch [38/500] - D Loss: 0.0450, G Loss: 6.2192
# Epoch [39/500] - D Loss: 0.0210, G Loss: 6.8818
# Epoch [40/500] - D Loss: 0.1736, G Loss: 7.8371
# Epoch [41/500] - D Loss: 0.0422, G Loss: 8.4915
# Epoch [42/500] - D Loss: 0.0945, G Loss: 6.9459
# Epoch [43/500] - D Loss: 0.1143, G Loss: 6.3512
# Epoch [44/500] - D Loss: 0.0391, G Loss: 7.1083
# Epoch [45/500] - D Loss: 0.0837, G Loss: 9.1778
# Epoch [46/500] - D Loss: 0.1336, G Loss: 8.2422
# Epoch [47/500] - D Loss: 0.0911, G Loss: 5.8609
# Epoch [48/500] - D Loss: 0.0814, G Loss: 6.2378
# Epoch [49/500] - D Loss: 0.1616, G Loss: 6.3232
# Epoch [50/500] - D Loss: 0.0944, G Loss: 7.8873
# Epoch [51/500] - D Loss: 0.1511, G Loss: 6.3522
# Epoch [52/500] - D Loss: 0.1045, G Loss: 7.9708
# Epoch [53/500] - D Loss: 0.0726, G Loss: 6.2380
# Epoch [54/500] - D Loss: 0.0749, G Loss: 6.3538
# Epoch [55/500] - D Loss: 0.0664, G Loss: 5.3948
# Epoch [56/500] - D Loss: 0.1265, G Loss: 6.1069
# Epoch [57/500] - D Loss: 0.0714, G Loss: 5.3712
# Epoch [58/500] - D Loss: 0.1346, G Loss: 5.6387
# Epoch [59/500] - D Loss: 0.0773, G Loss: 5.7513
# Epoch [60/500] - D Loss: 0.1061, G Loss: 6.0210
# Epoch [61/500] - D Loss: 0.0915, G Loss: 6.4517
# Epoch [62/500] - D Loss: 0.0958, G Loss: 5.7917
# Epoch [63/500] - D Loss: 0.0949, G Loss: 6.1330
# Epoch [64/500] - D Loss: 0.0397, G Loss: 6.8406
# Epoch [65/500] - D Loss: 0.2651, G Loss: 7.4527
# Epoch [66/500] - D Loss: 0.2243, G Loss: 8.4947
# Epoch [67/500] - D Loss: 0.0818, G Loss: 6.1223
# Epoch [68/500] - D Loss: 0.2104, G Loss: 6.6278
# Epoch [69/500] - D Loss: 0.1329, G Loss: 7.6744
# Epoch [70/500] - D Loss: 0.2489, G Loss: 7.3904
# Epoch [71/500] - D Loss: 0.1400, G Loss: 6.2226
# Epoch [72/500] - D Loss: 0.0643, G Loss: 6.2648
# Epoch [73/500] - D Loss: 0.1852, G Loss: 6.2068
# Epoch [74/500] - D Loss: 0.1868, G Loss: 5.2243
# Epoch [75/500] - D Loss: 0.1154, G Loss: 4.8771
# Epoch [76/500] - D Loss: 0.1377, G Loss: 4.9004
# Epoch [77/500] - D Loss: 0.1138, G Loss: 5.5959
# Epoch [78/500] - D Loss: 0.1032, G Loss: 5.8480
# Epoch [79/500] - D Loss: 0.0751, G Loss: 6.0326
# Epoch [80/500] - D Loss: 0.1784, G Loss: 5.8771
# Epoch [81/500] - D Loss: 0.1716, G Loss: 5.8960
# Epoch [82/500] - D Loss: 0.1667, G Loss: 5.3530
# Epoch [83/500] - D Loss: 0.0998, G Loss: 5.2751
# Epoch [84/500] - D Loss: 0.1813, G Loss: 5.9868
# Epoch [85/500] - D Loss: 0.1831, G Loss: 7.4434
# Epoch [86/500] - D Loss: 0.1303, G Loss: 6.0708
# Epoch [87/500] - D Loss: 0.1183, G Loss: 5.6128
# Epoch [88/500] - D Loss: 0.2800, G Loss: 5.8920
# Epoch [89/500] - D Loss: 0.1412, G Loss: 6.1894
# Epoch [90/500] - D Loss: 0.0654, G Loss: 5.9998
# Epoch [91/500] - D Loss: 0.3570, G Loss: 5.2281
# Epoch [92/500] - D Loss: 0.3605, G Loss: 5.3329
# Epoch [93/500] - D Loss: 0.0718, G Loss: 6.5734
# Epoch [94/500] - D Loss: 0.2392, G Loss: 5.9706
# Epoch [95/500] - D Loss: 0.1635, G Loss: 5.7437
# Epoch [96/500] - D Loss: 0.0999, G Loss: 5.7183
# Epoch [97/500] - D Loss: 0.0656, G Loss: 5.4306
# Epoch [98/500] - D Loss: 0.1466, G Loss: 5.4622
# Epoch [99/500] - D Loss: 0.1460, G Loss: 5.3856
# Epoch [100/500] - D Loss: 0.0626, G Loss: 5.8285
# Epoch [101/500] - D Loss: 0.1052, G Loss: 5.5568
# Epoch [102/500] - D Loss: 0.1403, G Loss: 5.4945
# Epoch [103/500] - D Loss: 0.0546, G Loss: 5.2018
# Epoch [104/500] - D Loss: 0.1108, G Loss: 5.4336
# Epoch [105/500] - D Loss: 0.0872, G Loss: 5.5460
# Epoch [106/500] - D Loss: 0.0451, G Loss: 5.7092
# Epoch [107/500] - D Loss: 0.0957, G Loss: 5.0710
# Epoch [108/500] - D Loss: 0.0941, G Loss: 5.2745
# Epoch [109/500] - D Loss: 0.0616, G Loss: 5.5783
# Epoch [110/500] - D Loss: 0.0657, G Loss: 5.3317
# Epoch [111/500] - D Loss: 0.1146, G Loss: 5.0999
# Epoch [112/500] - D Loss: 0.1050, G Loss: 5.4700
# Epoch [113/500] - D Loss: 0.0797, G Loss: 6.3591
# Epoch [114/500] - D Loss: 0.1411, G Loss: 6.7584
# Epoch [115/500] - D Loss: 0.1084, G Loss: 6.1989
# Epoch [116/500] - D Loss: 0.1092, G Loss: 5.9533
# Epoch [117/500] - D Loss: 0.1170, G Loss: 6.3933
# Epoch [118/500] - D Loss: 0.3004, G Loss: 8.8382
# Epoch [119/500] - D Loss: 0.1913, G Loss: 8.5127
# Epoch [120/500] - D Loss: 0.1229, G Loss: 5.7528
# Epoch [121/500] - D Loss: 0.1801, G Loss: 5.6011
# Epoch [122/500] - D Loss: 0.2218, G Loss: 5.2955
# Epoch [123/500] - D Loss: 0.1337, G Loss: 6.1838
# Epoch [124/500] - D Loss: 0.1055, G Loss: 6.0267
# Epoch [125/500] - D Loss: 0.1854, G Loss: 5.8497
# Epoch [126/500] - D Loss: 0.1548, G Loss: 5.6958
# Epoch [127/500] - D Loss: 0.1683, G Loss: 5.3745
# Epoch [128/500] - D Loss: 0.0769, G Loss: 5.7950
# Epoch [129/500] - D Loss: 0.1339, G Loss: 5.4011
# Epoch [130/500] - D Loss: 0.1592, G Loss: 5.5848
# Epoch [131/500] - D Loss: 0.1272, G Loss: 5.5764
# Epoch [132/500] - D Loss: 0.1162, G Loss: 5.7116
# Epoch [133/500] - D Loss: 0.0835, G Loss: 5.6082
# Epoch [134/500] - D Loss: 0.1414, G Loss: 5.2984
# Epoch [135/500] - D Loss: 0.1313, G Loss: 5.3171
# Epoch [136/500] - D Loss: 0.0900, G Loss: 5.3907
# Epoch [137/500] - D Loss: 0.1290, G Loss: 5.5557
# Epoch [138/500] - D Loss: 0.1621, G Loss: 5.5200
# Epoch [139/500] - D Loss: 0.0912, G Loss: 5.3303
# Epoch [140/500] - D Loss: 0.1185, G Loss: 5.7727
# Epoch [141/500] - D Loss: 0.1645, G Loss: 5.8009
# Epoch [142/500] - D Loss: 0.0748, G Loss: 5.8846
# Epoch [143/500] - D Loss: 0.1757, G Loss: 5.5253
# Epoch [144/500] - D Loss: 0.1781, G Loss: 5.0858
# Epoch [145/500] - D Loss: 0.0814, G Loss: 5.7615
# Epoch [146/500] - D Loss: 0.1166, G Loss: 5.6969
# Epoch [147/500] - D Loss: 0.1487, G Loss: 6.2389
# Epoch [148/500] - D Loss: 0.0933, G Loss: 6.5644
# Epoch [149/500] - D Loss: 0.1213, G Loss: 6.7864
# Epoch [150/500] - D Loss: 0.1626, G Loss: 6.1293
# Epoch [151/500] - D Loss: 0.1101, G Loss: 5.9504
# Epoch [152/500] - D Loss: 0.1040, G Loss: 6.3198
# Epoch [153/500] - D Loss: 0.1769, G Loss: 5.9388
# Epoch [154/500] - D Loss: 0.2561, G Loss: 6.0003
# Epoch [155/500] - D Loss: 0.1495, G Loss: 6.2669
# Epoch [156/500] - D Loss: 0.0961, G Loss: 6.8994
# Epoch [157/500] - D Loss: 0.2126, G Loss: 6.4765
# Epoch [158/500] - D Loss: 0.2626, G Loss: 5.6848
# Epoch [159/500] - D Loss: 0.0795, G Loss: 6.1588
# Epoch [160/500] - D Loss: 0.1369, G Loss: 6.3917
# Epoch [161/500] - D Loss: 0.1239, G Loss: 7.1428
# Epoch [162/500] - D Loss: 0.1405, G Loss: 6.2609
# Epoch [163/500] - D Loss: 0.0886, G Loss: 6.5072
# Epoch [164/500] - D Loss: 0.1230, G Loss: 6.4804
# Epoch [165/500] - D Loss: 0.1432, G Loss: 7.0567
# Epoch [166/500] - D Loss: 0.1571, G Loss: 6.5986
# Epoch [167/500] - D Loss: 0.1338, G Loss: 5.8557
# Epoch [168/500] - D Loss: 0.0966, G Loss: 6.1878
# Epoch [169/500] - D Loss: 0.2293, G Loss: 6.5881
# Epoch [170/500] - D Loss: 0.3807, G Loss: 6.9773
# Epoch [171/500] - D Loss: 0.2504, G Loss: 5.5991
# Epoch [172/500] - D Loss: 0.2310, G Loss: 5.7752
# Epoch [173/500] - D Loss: 0.2466, G Loss: 6.5277
# Epoch [174/500] - D Loss: 0.1937, G Loss: 5.1591
# Epoch [175/500] - D Loss: 0.2282, G Loss: 5.4565
# Epoch [176/500] - D Loss: 0.1991, G Loss: 6.0995
# Epoch [177/500] - D Loss: 0.2429, G Loss: 5.8926
# Epoch [178/500] - D Loss: 0.2503, G Loss: 5.6486
# Epoch [179/500] - D Loss: 0.1804, G Loss: 4.9863
# Epoch [180/500] - D Loss: 0.3168, G Loss: 4.0995
# Epoch [181/500] - D Loss: 0.2503, G Loss: 4.2405
# Epoch [182/500] - D Loss: 0.2042, G Loss: 4.6696
# Epoch [183/500] - D Loss: 0.2485, G Loss: 5.0367
# Epoch [184/500] - D Loss: 0.3328, G Loss: 5.4752
# Epoch [185/500] - D Loss: 0.1891, G Loss: 5.8022
# Epoch [186/500] - D Loss: 0.2344, G Loss: 5.1004
# Epoch [187/500] - D Loss: 0.2492, G Loss: 4.5072
# Epoch [188/500] - D Loss: 0.2305, G Loss: 4.3486
# Epoch [189/500] - D Loss: 0.2606, G Loss: 4.6597
# Epoch [190/500] - D Loss: 0.2163, G Loss: 5.0502
# Epoch [191/500] - D Loss: 0.2655, G Loss: 4.8770
# Epoch [192/500] - D Loss: 0.2928, G Loss: 4.6815
# Epoch [193/500] - D Loss: 0.2283, G Loss: 5.0781
# Epoch [194/500] - D Loss: 0.3410, G Loss: 4.4886
# Epoch [195/500] - D Loss: 0.3075, G Loss: 4.4310
# Epoch [196/500] - D Loss: 0.1364, G Loss: 4.7806
# Epoch [197/500] - D Loss: 0.2839, G Loss: 4.8421
# Epoch [198/500] - D Loss: 0.4348, G Loss: 4.6122
# Epoch [199/500] - D Loss: 0.1877, G Loss: 5.0238
# Epoch [200/500] - D Loss: 0.2014, G Loss: 4.9137
# Epoch [201/500] - D Loss: 0.1971, G Loss: 5.3307
# Epoch [202/500] - D Loss: 0.2448, G Loss: 5.1274
# Epoch [203/500] - D Loss: 0.2694, G Loss: 5.6974
# Epoch [204/500] - D Loss: 0.1960, G Loss: 5.3884
# Epoch [205/500] - D Loss: 0.2274, G Loss: 5.9371
# Epoch [206/500] - D Loss: 0.3555, G Loss: 5.4151
# Epoch [207/500] - D Loss: 0.2765, G Loss: 4.8425
# Epoch [208/500] - D Loss: 0.2604, G Loss: 4.6233
# Epoch [209/500] - D Loss: 0.3469, G Loss: 4.3862
# Epoch [210/500] - D Loss: 0.3056, G Loss: 4.5054
# Epoch [211/500] - D Loss: 0.1883, G Loss: 5.1814
# Epoch [212/500] - D Loss: 0.2641, G Loss: 5.4073
# Epoch [213/500] - D Loss: 0.2254, G Loss: 5.9973
# Epoch [214/500] - D Loss: 0.3803, G Loss: 6.2116
# Epoch [215/500] - D Loss: 0.2939, G Loss: 5.5015
# Epoch [216/500] - D Loss: 0.3603, G Loss: 4.8146
# Epoch [217/500] - D Loss: 0.2986, G Loss: 5.1194
# Epoch [218/500] - D Loss: 0.2088, G Loss: 5.0441
# Epoch [219/500] - D Loss: 0.3369, G Loss: 4.7511
# Epoch [220/500] - D Loss: 0.4144, G Loss: 4.9404
# Epoch [221/500] - D Loss: 0.3886, G Loss: 4.9432
# Epoch [222/500] - D Loss: 0.2262, G Loss: 4.8445
# Epoch [223/500] - D Loss: 0.3910, G Loss: 4.6976
# Epoch [224/500] - D Loss: 0.3653, G Loss: 4.8600
# Epoch [225/500] - D Loss: 0.2280, G Loss: 4.8490
# Epoch [226/500] - D Loss: 0.3281, G Loss: 4.4775
# Epoch [227/500] - D Loss: 0.3704, G Loss: 4.5389
# Epoch [228/500] - D Loss: 0.3062, G Loss: 4.5396
# Epoch [229/500] - D Loss: 0.4815, G Loss: 4.6041
# Epoch [230/500] - D Loss: 0.2553, G Loss: 4.5144
# Epoch [231/500] - D Loss: 0.3446, G Loss: 4.8846
# Epoch [232/500] - D Loss: 0.4300, G Loss: 4.5640
# Epoch [233/500] - D Loss: 0.2903, G Loss: 4.5389
# Epoch [234/500] - D Loss: 0.3378, G Loss: 4.7429
# Epoch [235/500] - D Loss: 0.3797, G Loss: 4.0588
# Epoch [236/500] - D Loss: 0.2464, G Loss: 4.3799
# Epoch [237/500] - D Loss: 0.3470, G Loss: 4.4611
# Epoch [238/500] - D Loss: 0.6259, G Loss: 4.9044
# Epoch [239/500] - D Loss: 0.4105, G Loss: 4.3425
# Epoch [240/500] - D Loss: 0.4618, G Loss: 3.4966
# Epoch [241/500] - D Loss: 0.2673, G Loss: 4.0867
# Epoch [242/500] - D Loss: 0.3705, G Loss: 3.9648
# Epoch [243/500] - D Loss: 0.5409, G Loss: 3.5823
# Epoch [244/500] - D Loss: 0.4436, G Loss: 3.5656
# Epoch [245/500] - D Loss: 0.2170, G Loss: 4.2290
# Epoch [246/500] - D Loss: 0.2743, G Loss: 4.1496
# Epoch [247/500] - D Loss: 0.5333, G Loss: 3.7980
# Epoch [248/500] - D Loss: 0.3207, G Loss: 4.2570
# Epoch [249/500] - D Loss: 0.2487, G Loss: 4.3052
# Epoch [250/500] - D Loss: 0.3838, G Loss: 4.4405
# Epoch [251/500] - D Loss: 0.5248, G Loss: 4.4808
# Epoch [252/500] - D Loss: 0.1938, G Loss: 4.6193
# Epoch [253/500] - D Loss: 0.2803, G Loss: 4.3855
# Epoch [254/500] - D Loss: 0.5552, G Loss: 3.9412
# Epoch [255/500] - D Loss: 0.4189, G Loss: 4.0564
# Epoch [256/500] - D Loss: 0.3011, G Loss: 4.1777
# Epoch [257/500] - D Loss: 0.3853, G Loss: 3.9719
# Epoch [258/500] - D Loss: 0.4442, G Loss: 3.9929
# Epoch [259/500] - D Loss: 0.3718, G Loss: 4.0821
# Epoch [260/500] - D Loss: 0.2106, G Loss: 4.5139
# Epoch [261/500] - D Loss: 0.2572, G Loss: 4.2889
# Epoch [262/500] - D Loss: 0.5208, G Loss: 3.8541
# Epoch [263/500] - D Loss: 0.4313, G Loss: 4.1212
# Epoch [264/500] - D Loss: 0.2116, G Loss: 4.3731
# Epoch [265/500] - D Loss: 0.3902, G Loss: 3.9565
# Epoch [266/500] - D Loss: 0.4071, G Loss: 3.8676
# Epoch [267/500] - D Loss: 0.3851, G Loss: 3.8152
# Epoch [268/500] - D Loss: 0.5021, G Loss: 3.7217
# Epoch [269/500] - D Loss: 0.3519, G Loss: 4.1474
# Epoch [270/500] - D Loss: 0.5027, G Loss: 3.6009
# Epoch [271/500] - D Loss: 0.3778, G Loss: 3.6381
# Epoch [272/500] - D Loss: 0.3410, G Loss: 4.2825
# Epoch [273/500] - D Loss: 0.5543, G Loss: 3.8218
# Epoch [274/500] - D Loss: 0.6550, G Loss: 3.6621
# Epoch [275/500] - D Loss: 0.2854, G Loss: 3.8628
# Epoch [276/500] - D Loss: 0.3879, G Loss: 3.7128
# Epoch [277/500] - D Loss: 0.7594, G Loss: 3.4611
# Epoch [278/500] - D Loss: 0.5193, G Loss: 3.5903
# Epoch [279/500] - D Loss: 0.2517, G Loss: 3.8219
# Epoch [280/500] - D Loss: 0.2474, G Loss: 3.7487
# Epoch [281/500] - D Loss: 0.3757, G Loss: 3.2643
# Epoch [282/500] - D Loss: 0.3779, G Loss: 3.6984
# Epoch [283/500] - D Loss: 0.4202, G Loss: 3.8148
# Epoch [284/500] - D Loss: 0.3424, G Loss: 3.8256
# Epoch [285/500] - D Loss: 0.3322, G Loss: 4.1505
# Epoch [286/500] - D Loss: 0.4100, G Loss: 3.6757
# Epoch [287/500] - D Loss: 0.3404, G Loss: 3.7964
# Epoch [288/500] - D Loss: 0.2896, G Loss: 4.2441
# Epoch [289/500] - D Loss: 0.4766, G Loss: 3.8315
# Epoch [290/500] - D Loss: 0.8995, G Loss: 3.1810
# Epoch [291/500] - D Loss: 0.4236, G Loss: 3.2281
# Epoch [292/500] - D Loss: 0.4111, G Loss: 3.3776
# Epoch [293/500] - D Loss: 0.6554, G Loss: 3.6285
# Epoch [294/500] - D Loss: 0.5292, G Loss: 4.3885
# Epoch [295/500] - D Loss: 0.6051, G Loss: 4.2135
# Epoch [296/500] - D Loss: 0.4631, G Loss: 4.1146
# Epoch [297/500] - D Loss: 0.5318, G Loss: 3.6388
# Epoch [298/500] - D Loss: 0.5984, G Loss: 2.9950
# Epoch [299/500] - D Loss: 0.5353, G Loss: 2.8736
# Epoch [300/500] - D Loss: 0.5214, G Loss: 2.8725
# Epoch [301/500] - D Loss: 0.5731, G Loss: 2.7710
# Epoch [302/500] - D Loss: 0.3874, G Loss: 3.0831
# Epoch [303/500] - D Loss: 0.3840, G Loss: 3.2716
# Epoch [304/500] - D Loss: 0.4399, G Loss: 3.2094
# Epoch [305/500] - D Loss: 0.4885, G Loss: 3.1677
# Epoch [306/500] - D Loss: 0.4076, G Loss: 3.4431
# Epoch [307/500] - D Loss: 0.3725, G Loss: 3.6575
# Epoch [308/500] - D Loss: 0.4510, G Loss: 3.5465
# Epoch [309/500] - D Loss: 0.5390, G Loss: 3.4118
# Epoch [310/500] - D Loss: 0.4957, G Loss: 3.5229
# Epoch [311/500] - D Loss: 0.4392, G Loss: 3.4856
# Epoch [312/500] - D Loss: 0.3634, G Loss: 3.4583
# Epoch [313/500] - D Loss: 0.4487, G Loss: 3.1728
# Epoch [314/500] - D Loss: 0.5517, G Loss: 3.0048
# Epoch [315/500] - D Loss: 0.5544, G Loss: 2.9968
# Epoch [316/500] - D Loss: 0.4157, G Loss: 3.6171
# Epoch [317/500] - D Loss: 0.6197, G Loss: 3.3105
# Epoch [318/500] - D Loss: 0.4115, G Loss: 4.1748
# Epoch [319/500] - D Loss: 0.6125, G Loss: 3.7602
# Epoch [320/500] - D Loss: 0.7346, G Loss: 3.1148
# Epoch [321/500] - D Loss: 0.3819, G Loss: 3.0573
# Epoch [322/500] - D Loss: 0.3291, G Loss: 2.8821
# Epoch [323/500] - D Loss: 0.2951, G Loss: 2.9503
# Epoch [324/500] - D Loss: 0.4704, G Loss: 2.7937
# Epoch [325/500] - D Loss: 0.8549, G Loss: 2.3113
# Epoch [326/500] - D Loss: 0.4465, G Loss: 2.8557
# Epoch [327/500] - D Loss: 0.3113, G Loss: 3.1545
# Epoch [328/500] - D Loss: 0.3405, G Loss: 3.2403
# Epoch [329/500] - D Loss: 0.4091, G Loss: 3.1760
# Epoch [330/500] - D Loss: 0.3771, G Loss: 3.3953
# Epoch [331/500] - D Loss: 0.4328, G Loss: 3.2250
# Epoch [332/500] - D Loss: 0.4018, G Loss: 3.1803
# Epoch [333/500] - D Loss: 0.4157, G Loss: 3.2439
# Epoch [334/500] - D Loss: 0.5083, G Loss: 3.5163
# Epoch [335/500] - D Loss: 0.5116, G Loss: 3.3529
# Epoch [336/500] - D Loss: 0.5043, G Loss: 3.5046
# Epoch [337/500] - D Loss: 0.6807, G Loss: 3.4167
# Epoch [338/500] - D Loss: 0.6015, G Loss: 3.5311
# Epoch [339/500] - D Loss: 0.4150, G Loss: 3.8356
# Epoch [340/500] - D Loss: 0.4948, G Loss: 3.6083
# Epoch [341/500] - D Loss: 0.5745, G Loss: 3.2837
# Epoch [342/500] - D Loss: 0.5076, G Loss: 3.2190
# Epoch [343/500] - D Loss: 0.5085, G Loss: 3.1046
# Epoch [344/500] - D Loss: 0.4394, G Loss: 3.0872
# Epoch [345/500] - D Loss: 0.5269, G Loss: 2.8573
# Epoch [346/500] - D Loss: 0.5016, G Loss: 2.9867
# Epoch [347/500] - D Loss: 0.4593, G Loss: 3.1319
# Epoch [348/500] - D Loss: 0.3297, G Loss: 3.3452
# Epoch [349/500] - D Loss: 0.5357, G Loss: 3.0340
# Epoch [350/500] - D Loss: 0.5533, G Loss: 3.2941
# Epoch [351/500] - D Loss: 0.5229, G Loss: 3.3392
# Epoch [352/500] - D Loss: 0.5750, G Loss: 3.3140
# Epoch [353/500] - D Loss: 0.4909, G Loss: 3.5662
# Epoch [354/500] - D Loss: 0.4653, G Loss: 3.5902
# Epoch [355/500] - D Loss: 0.3932, G Loss: 3.6016
# Epoch [356/500] - D Loss: 0.3895, G Loss: 3.8177
# Epoch [357/500] - D Loss: 0.6153, G Loss: 3.3420
# Epoch [358/500] - D Loss: 0.6844, G Loss: 3.3168
# Epoch [359/500] - D Loss: 0.6362, G Loss: 3.4537
# Epoch [360/500] - D Loss: 0.5977, G Loss: 3.2804
# Epoch [361/500] - D Loss: 0.5258, G Loss: 3.2551
# Epoch [362/500] - D Loss: 0.5668, G Loss: 3.3221
# Epoch [363/500] - D Loss: 0.4413, G Loss: 3.3004
# Epoch [364/500] - D Loss: 0.6463, G Loss: 3.0896
# Epoch [365/500] - D Loss: 0.4326, G Loss: 3.5465
# Epoch [366/500] - D Loss: 0.4226, G Loss: 3.4415
# Epoch [367/500] - D Loss: 0.5078, G Loss: 3.2505
# Epoch [368/500] - D Loss: 0.4390, G Loss: 3.3343
# Epoch [369/500] - D Loss: 0.4675, G Loss: 3.2432
# Epoch [370/500] - D Loss: 0.6101, G Loss: 3.0392
# Epoch [371/500] - D Loss: 0.5158, G Loss: 3.1507
# Epoch [372/500] - D Loss: 0.2966, G Loss: 3.6666
# Epoch [373/500] - D Loss: 0.4151, G Loss: 3.4152
# Epoch [374/500] - D Loss: 0.6177, G Loss: 3.1197
# Epoch [375/500] - D Loss: 0.4944, G Loss: 3.3425
# Epoch [376/500] - D Loss: 0.3661, G Loss: 3.6402
# Epoch [377/500] - D Loss: 0.5966, G Loss: 3.2140
# Epoch [378/500] - D Loss: 0.4251, G Loss: 3.3914
# Epoch [379/500] - D Loss: 0.5246, G Loss: 2.9826
# Epoch [380/500] - D Loss: 0.6584, G Loss: 2.7183
# Epoch [381/500] - D Loss: 0.6714, G Loss: 2.6685
# Epoch [382/500] - D Loss: 0.4867, G Loss: 2.7556
# Epoch [383/500] - D Loss: 0.4803, G Loss: 2.9163
# Epoch [384/500] - D Loss: 0.3596, G Loss: 3.2401
# Epoch [385/500] - D Loss: 0.4838, G Loss: 3.0648
# Epoch [386/500] - D Loss: 0.5967, G Loss: 2.9843
# Epoch [387/500] - D Loss: 0.5512, G Loss: 2.9969
# Epoch [388/500] - D Loss: 0.4104, G Loss: 3.2737
# Epoch [389/500] - D Loss: 0.5155, G Loss: 3.1446
# Epoch [390/500] - D Loss: 0.5061, G Loss: 3.3228
# Epoch [391/500] - D Loss: 0.5392, G Loss: 3.9663
# Epoch [392/500] - D Loss: 0.7642, G Loss: 3.7371
# Epoch [393/500] - D Loss: 0.5909, G Loss: 4.1940
# Epoch [394/500] - D Loss: 0.4682, G Loss: 4.3540
# Epoch [395/500] - D Loss: 0.6041, G Loss: 3.5995
# Epoch [396/500] - D Loss: 0.5147, G Loss: 3.4023
# Epoch [397/500] - D Loss: 0.4469, G Loss: 3.4743
# Epoch [398/500] - D Loss: 0.4168, G Loss: 3.4249
# Epoch [399/500] - D Loss: 0.5510, G Loss: 3.4124
# Epoch [400/500] - D Loss: 0.4119, G Loss: 4.1036
# Epoch [401/500] - D Loss: 0.5090, G Loss: 3.6701
# Epoch [402/500] - D Loss: 0.6594, G Loss: 3.3070
# Epoch [403/500] - D Loss: 0.6702, G Loss: 3.1151
# Epoch [404/500] - D Loss: 0.4869, G Loss: 3.3405
# Epoch [405/500] - D Loss: 0.4921, G Loss: 3.4165
# Epoch [406/500] - D Loss: 0.5986, G Loss: 3.3422
# Epoch [407/500] - D Loss: 0.5257, G Loss: 3.3457
# Epoch [408/500] - D Loss: 0.5173, G Loss: 3.1484
# Epoch [409/500] - D Loss: 0.5922, G Loss: 3.3145
# Epoch [410/500] - D Loss: 0.6154, G Loss: 3.2436
# Epoch [411/500] - D Loss: 0.5510, G Loss: 3.4901
# Epoch [412/500] - D Loss: 0.5609, G Loss: 3.4534
# Epoch [413/500] - D Loss: 0.5305, G Loss: 3.3803
# Epoch [414/500] - D Loss: 0.7034, G Loss: 3.0225
# Epoch [415/500] - D Loss: 0.6588, G Loss: 3.0600
# Epoch [416/500] - D Loss: 0.4190, G Loss: 3.4462
# Epoch [417/500] - D Loss: 0.3960, G Loss: 3.4184
# Epoch [418/500] - D Loss: 0.4503, G Loss: 2.9488
# Epoch [419/500] - D Loss: 0.4875, G Loss: 2.9280
# Epoch [420/500] - D Loss: 0.5732, G Loss: 2.9786
# Epoch [421/500] - D Loss: 0.4126, G Loss: 3.1416
# Epoch [422/500] - D Loss: 0.5320, G Loss: 3.1061
# Epoch [423/500] - D Loss: 0.3755, G Loss: 3.4213
# Epoch [424/500] - D Loss: 0.5163, G Loss: 3.1629
# Epoch [425/500] - D Loss: 0.6339, G Loss: 2.8265
# Epoch [426/500] - D Loss: 0.6387, G Loss: 2.9668
# Epoch [427/500] - D Loss: 0.3775, G Loss: 3.2711
# Epoch [428/500] - D Loss: 0.4147, G Loss: 3.3272
# Epoch [429/500] - D Loss: 0.6407, G Loss: 2.9964
# Epoch [430/500] - D Loss: 0.6624, G Loss: 2.9447
# Epoch [431/500] - D Loss: 0.5164, G Loss: 2.9612
# Epoch [432/500] - D Loss: 0.3927, G Loss: 3.0317
# Epoch [433/500] - D Loss: 0.4180, G Loss: 3.0646
# Epoch [434/500] - D Loss: 0.5275, G Loss: 2.8452
# Epoch [435/500] - D Loss: 0.5210, G Loss: 2.9667
# Epoch [436/500] - D Loss: 0.4822, G Loss: 3.0252
# Epoch [437/500] - D Loss: 0.4972, G Loss: 2.7840
# Epoch [438/500] - D Loss: 0.6132, G Loss: 2.9034
# Epoch [439/500] - D Loss: 0.5688, G Loss: 2.7853
# Epoch [440/500] - D Loss: 0.4526, G Loss: 2.9738
# Epoch [441/500] - D Loss: 0.4319, G Loss: 3.1380
# Epoch [442/500] - D Loss: 0.4734, G Loss: 3.1908
# Epoch [443/500] - D Loss: 0.7635, G Loss: 3.0753
# Epoch [444/500] - D Loss: 0.5339, G Loss: 3.5559
# Epoch [445/500] - D Loss: 0.3996, G Loss: 3.8010
# Epoch [446/500] - D Loss: 0.6929, G Loss: 3.6902
# Epoch [447/500] - D Loss: 0.6109, G Loss: 3.5088
# Epoch [448/500] - D Loss: 0.4435, G Loss: 4.3127
# Epoch [449/500] - D Loss: 0.4978, G Loss: 3.9025
# Epoch [450/500] - D Loss: 0.6089, G Loss: 3.5922
# Epoch [451/500] - D Loss: 0.6053, G Loss: 3.3572
# Epoch [452/500] - D Loss: 0.7260, G Loss: 3.6667
# Epoch [453/500] - D Loss: 0.6858, G Loss: 2.9369
# Epoch [454/500] - D Loss: 0.3164, G Loss: 3.3082
# Epoch [455/500] - D Loss: 0.4584, G Loss: 2.8926
# Epoch [456/500] - D Loss: 0.6100, G Loss: 2.8175
# Epoch [457/500] - D Loss: 0.5698, G Loss: 3.0378
# Epoch [458/500] - D Loss: 0.4633, G Loss: 3.3977
# Epoch [459/500] - D Loss: 0.5899, G Loss: 3.0467
# Epoch [460/500] - D Loss: 0.5867, G Loss: 2.9983
# Epoch [461/500] - D Loss: 0.4773, G Loss: 3.2114
# Epoch [462/500] - D Loss: 0.4748, G Loss: 3.2869
# Epoch [463/500] - D Loss: 0.7681, G Loss: 2.5393
# Epoch [464/500] - D Loss: 0.6022, G Loss: 2.4210
# Epoch [465/500] - D Loss: 0.4342, G Loss: 2.7828
# Epoch [466/500] - D Loss: 0.4945, G Loss: 2.8085
# Epoch [467/500] - D Loss: 0.5472, G Loss: 2.7596
# Epoch [468/500] - D Loss: 0.4908, G Loss: 2.9599
# Epoch [469/500] - D Loss: 0.5161, G Loss: 3.0603
# Epoch [470/500] - D Loss: 0.5485, G Loss: 3.1584
# Epoch [471/500] - D Loss: 0.4737, G Loss: 3.5169
# Epoch [472/500] - D Loss: 0.6717, G Loss: 3.1952
# Epoch [473/500] - D Loss: 0.6164, G Loss: 3.2401
# Epoch [474/500] - D Loss: 0.5080, G Loss: 3.2933
# Epoch [475/500] - D Loss: 0.5033, G Loss: 3.0734
# Epoch [476/500] - D Loss: 0.4711, G Loss: 3.1580
# Epoch [477/500] - D Loss: 0.5770, G Loss: 3.0035
# Epoch [478/500] - D Loss: 0.5362, G Loss: 3.3034
# Epoch [479/500] - D Loss: 0.4823, G Loss: 3.6145
# Epoch [480/500] - D Loss: 0.6118, G Loss: 3.3382
# Epoch [481/500] - D Loss: 0.9141, G Loss: 2.5713
# Epoch [482/500] - D Loss: 0.4231, G Loss: 3.1514
# Epoch [483/500] - D Loss: 0.3735, G Loss: 3.1699
# Epoch [484/500] - D Loss: 0.6370, G Loss: 2.7953
# Epoch [485/500] - D Loss: 0.4968, G Loss: 2.9876
# Epoch [486/500] - D Loss: 0.4248, G Loss: 2.9686
# Epoch [487/500] - D Loss: 0.5941, G Loss: 3.0072
# Epoch [488/500] - D Loss: 0.7473, G Loss: 3.0911
# Epoch [489/500] - D Loss: 0.6698, G Loss: 2.8972
# Epoch [490/500] - D Loss: 0.5186, G Loss: 3.0325
# Epoch [491/500] - D Loss: 0.6913, G Loss: 2.9510
# Epoch [492/500] - D Loss: 0.8801, G Loss: 2.9694
# Epoch [493/500] - D Loss: 0.5567, G Loss: 3.3364
# Epoch [494/500] - D Loss: 0.4658, G Loss: 3.2703
# Epoch [495/500] - D Loss: 0.6874, G Loss: 2.5867
# Epoch [496/500] - D Loss: 0.8974, G Loss: 2.1737
# Epoch [497/500] - D Loss: 0.6225, G Loss: 2.2911
# Epoch [498/500] - D Loss: 0.4652, G Loss: 2.4699
# Epoch [499/500] - D Loss: 0.4867, G Loss: 2.5604
# Epoch [500/500] - D Loss: 0.6176, G Loss: 2.5105

# %%
# plot the losses and discriminator outputs
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(losses[:, 0], label='Discriminator Loss')
plt.plot(losses[:, 1], label='Generator Loss')
plt.title('Losses')
plt.xlabel('Epoch')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(discriminator_outputs[:, 0], label='Discriminator Output (Real)')
plt.plot(discriminator_outputs[:, 1], label='Discriminator Output (Fake)')
plt.title('Discriminator Outputs')
plt.xlabel('Epoch')
plt.legend()
plt.show()
# if observed more in detail, the discriminator and generator loss iterate, this means
# that when the discriminator goes up and it starts to discriminate very well, the generator
# realizes and starts to generate better images, but then the discriminator has more issues to distinguis
# so it is a bucle, where the losses go up and down.

# %%
# visualize some samples
g_net.eval() # set generator to evaluation mode
with torch.no_grad():
    noise = torch.randn(16, 64).to(device) # generate 16 random noise vectors
    fake_images = g_net(noise).cpu() # generate fake images and move to CPU
    fake_images = fake_images.view(-1, 1, 28, 28) # reshape to image format
    fig, axes = plt.subplots(4, 4, figsize=(8, 8))
    for i in range(16):
        ax = axes[i//4, i%4]
        ax.imshow(fake_images[i].squeeze(), cmap='gray')
        ax.axis('off')
    plt.show()
